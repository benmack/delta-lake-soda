# %% [markdown]
# # Soda scan all batches

# %% [markdown]
# ## Setup

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import datetime
from ipywidgets import Output
import pandas as pd
from pathlib import Path 
from soda.scan import Scan
from soda.common.json_helper import JsonHelper

from delta import *
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.functions import input_file_name, split, regexp_extract, to_timestamp, explode

from utils.data_generation import FakerProfileDataSnapshot
from utils.soda_utils import build_scan_results, save_scan_results_with_spark_as_json

# %%
from soda.scan import Scan
from soda.common.json_helper import JsonHelper

def build_scan_results(scan) -> dict:

    checks = [
        check.get_cloud_dict() for check in scan._checks if check.outcome is not None and check.archetype is None
    ]
    autoamted_monitoring_checks = [
        check.get_cloud_dict()
        for check in scan._checks
        if check.outcome is not None and check.archetype is not None
    ]

    # TODO: [SODA-608] separate profile columns and sample tables by aligning with the backend team
    profiling = [
        profile_table.get_cloud_dict()
        for profile_table in scan._profile_columns_result_tables + scan._sample_tables_result_tables
    ]

    return JsonHelper.to_jsonnable(  # type: ignore
        {
            "definitionName": scan._scan_definition_name,
            "defaultDataSource": scan._data_source_name,
            "dataTimestamp": scan._data_timestamp,
            "scanStartTimestamp": scan._scan_start_timestamp,
            "scanEndTimestamp": scan._scan_end_timestamp,
            "hasErrors": scan.has_error_logs(),
            "hasWarnings": scan.has_check_warns(),
            "hasFailures": scan.has_check_fails(),
            "metrics": [metric.get_cloud_dict() for metric in scan._metrics],
            # If archetype is not None, it means that check is automated monitoring
            "checks": checks,
            # TODO Queries are not supported by Soda Cloud yet.
            # "queries": [query.get_cloud_dict() for query in scan._queries],
            "automatedMonitoringChecks": autoamted_monitoring_checks,
            "profiling": profiling,
            "metadata": [
                discover_tables_result.get_cloud_dict()
                for discover_tables_result in scan._discover_tables_result_tables
            ],
            "logs": [log.get_cloud_dict() for log in scan._logs.logs],
        }
    )

# %%
from delta import *

# %%
from pyspark.sql import SparkSession
from delta import *

builder = SparkSession.builder.appName("data-pipeline") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
# object for data generation
datagen = FakerProfileDataSnapshot(
    data_dir=str(Path('./data').resolve())
)
# clean landing storage
datagen.delete_batches_in_landing_dir()
datagen.delete_bronze_dir()
datagen.delete_bronze_scan_results_dir()

# %% [markdown]
# ## Parameters

# %%
read_csv_options = {'header': 'true', 'inferSchema': 'true', 'delimiter': ',', 'quote': '"', 'multiLine': 'true'}

# %%
location_landing = datagen.landing_dir
location_bronze = datagen.bronze_dir
location_bronze_scan_results = datagen.bronze_scan_results_dir

# %%
sodacl_yaml_str = '''
checks for snapshot:
  - freshness(_delivery_date, FAKE_NOW) < 8d
  - schema:
      fail:
        when required column missing:
          - id
          - mail
          - birthdate
          - _delivery_date  
  - row_count > 0
  - duplicate_count(id) = 0
  - duplicate_count(mail) = 0
  - missing_count(id) = 0
  - invalid_count(mail) = 0:
      valid format: email
  - invalid_percent(birthdate) = 0:
      valid length: 10
discover tables:
  tables:
    - include snapshot
profile columns:
  columns:
    - snapshot.%
'''

# %% [markdown]
# ## Processing all patches

# %%
for batch_id in range(1, 8):
    print('batch id :', batch_id)

    print('land file')
    path_csv = datagen.land_batch(batch_id)
    print(path_csv)

    print('ingest data to bronce delta table')
    df_landing = spark.read.format('csv').options(**read_csv_options).load(str(path_csv)) \
        .withColumn("_delivery_date", 
                    to_timestamp(
                        regexp_extract(
                            input_file_name(), '.*_(.*).csv$', 1
                        )
                    )
                   )
    df_landing.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').save(location_bronze)

    print('recreate table')
    spark.sql('DROP TABLE IF EXISTS snapshot')
    spark.sql(f'CREATE TABLE IF NOT EXISTS snapshot USING DELTA LOCATION "{location_bronze}"')

    print('delete data in landing zone')
    datagen.delete_batches_in_landing_dir()

    print('prepare soda scan')
    df_raw = spark.sql('select * from snapshot')
    delta_history = spark.sql(f'DESCRIBE HISTORY snapshot').toPandas()
    display(delta_history)
    delta_table_version = max(delta_history['version'])
    
    scan = Scan()
    scan.disable_telemetry()
    scan.set_data_source_name('snapshot')
    scan.add_spark_session(spark, 'snapshot')
    
    # with every delivery, the fake now of processing and scanning is always two days later than the delivery date
    fake_now = datetime.date.fromisoformat('2022-08-12') + datetime.timedelta(days=(7 * batch_id) + ((batch_id - 1) * 2))
    print('fake_now:', fake_now)
    scan.add_variables({"FAKE_NOW": f"{fake_now} 00:00:00"})
    
    scan.add_sodacl_yaml_str(sodacl_yaml_str)
    scan.set_verbose(False) # this does not stop the scan.execute() call to print all kind of out put in this notebook
    
    print('soda scan')
    # we avoid it with the following two lines instead
    output = Output()
    with output:
        exit_code = scan.execute()
    print('exit_code:', exit_code)
    
    print('build scan result')
    scan_results = build_scan_results(scan)
    scan_results['delta_version'] = max(delta_history['version'])
    print('store scan result')
    filepath_scan_result = location_bronze_scan_results + f'/scan_results_{delta_table_version}.json'
    print(filepath_scan_result)
    rdd = spark.sparkContext.parallelize([JsonHelper.to_json(scan_results)])
    rdd.coalesce(1).saveAsTextFile(filepath_scan_result)
# Out:
# batch id : 1
# land file
# /home/jovyan/work/data/landing/snapshot_2022-08-19.csv
# ingest data to bronce delta table
# recreate table
# delete data in landing zone
# prepare soda scan
#    version               timestamp userId userName operation  \
# 0        0 2022-08-21 16:45:23.128   None     None     WRITE
#
#                           operationParameters   job notebook clusterId  \
# 0  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
#
#    readVersion isolationLevel  isBlindAppend  \
# 0          NaN   Serializable          False
#
#                                     operationMetrics userMetadata  \
# 0  {'numOutputRows': '4', 'numOutputBytes': '3309...         None
#
#                             engineInfo
# 0  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# fake_now: 2022-08-19
# soda scan
# exit_code: 0
# build scan result
# store scan result
# /home/jovyan/work/data/bronze_scan_results/scan_results_0.json
# batch id : 2
# land file
# /home/jovyan/work/data/landing/snapshot_2022-08-26.csv
# ingest data to bronce delta table
# recreate table
# delete data in landing zone
# prepare soda scan
#    version               timestamp userId userName operation  \
# 0        1 2022-08-21 16:46:14.282   None     None     WRITE
# 1        0 2022-08-21 16:45:23.128   None     None     WRITE
#
#                           operationParameters   job notebook clusterId  \
# 0  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 1  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
#
#    readVersion isolationLevel  isBlindAppend  \
# 0          0.0   Serializable          False
# 1          NaN   Serializable          False
#
#                                     operationMetrics userMetadata  \
# 0  {'numOutputRows': '6', 'numOutputBytes': '3561...         None
# 1  {'numOutputRows': '4', 'numOutputBytes': '3309...         None
#
#                             engineInfo
# 0  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 1  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# fake_now: 2022-08-28
# soda scan
# exit_code: 0
# build scan result
# store scan result
# /home/jovyan/work/data/bronze_scan_results/scan_results_1.json
# batch id : 3
# land file
# /home/jovyan/work/data/landing/snapshot_2022-09-02.csv
# ingest data to bronce delta table
# recreate table
# delete data in landing zone
# prepare soda scan
#    version               timestamp userId userName operation  \
# 0        2 2022-08-21 16:46:45.546   None     None     WRITE
# 1        1 2022-08-21 16:46:14.282   None     None     WRITE
# 2        0 2022-08-21 16:45:23.128   None     None     WRITE
#
#                           operationParameters   job notebook clusterId  \
# 0  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 1  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 2  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
#
#    readVersion isolationLevel  isBlindAppend  \
# 0          1.0   Serializable          False
# 1          0.0   Serializable          False
# 2          NaN   Serializable          False
#
#                                     operationMetrics userMetadata  \
# 0  {'numOutputRows': '7', 'numOutputBytes': '3662...         None
# 1  {'numOutputRows': '6', 'numOutputBytes': '3561...         None
# 2  {'numOutputRows': '4', 'numOutputBytes': '3309...         None
#
#                             engineInfo
# 0  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 1  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 2  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# fake_now: 2022-09-06
# soda scan
# exit_code: 0
# build scan result
# store scan result
# /home/jovyan/work/data/bronze_scan_results/scan_results_2.json
# batch id : 4
# land file
# /home/jovyan/work/data/landing/snapshot_2022-09-09.csv
# ingest data to bronce delta table
# recreate table
# delete data in landing zone
# prepare soda scan
#    version               timestamp userId userName operation  \
# 0        3 2022-08-21 16:47:16.839   None     None     WRITE
# 1        2 2022-08-21 16:46:45.546   None     None     WRITE
# 2        1 2022-08-21 16:46:14.282   None     None     WRITE
# 3        0 2022-08-21 16:45:23.128   None     None     WRITE
#
#                           operationParameters   job notebook clusterId  \
# 0  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 1  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 2  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 3  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
#
#    readVersion isolationLevel  isBlindAppend  \
# 0          2.0   Serializable          False
# 1          1.0   Serializable          False
# 2          0.0   Serializable          False
# 3          NaN   Serializable          False
#
#                                     operationMetrics userMetadata  \
# 0  {'numOutputRows': '7', 'numOutputBytes': '5246...         None
# 1  {'numOutputRows': '7', 'numOutputBytes': '3662...         None
# 2  {'numOutputRows': '6', 'numOutputBytes': '3561...         None
# 3  {'numOutputRows': '4', 'numOutputBytes': '3309...         None
#
#                             engineInfo
# 0  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 1  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 2  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 3  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# fake_now: 2022-09-15
# soda scan
# exit_code: 0
# build scan result
# store scan result
# /home/jovyan/work/data/bronze_scan_results/scan_results_3.json
# batch id : 5
# land file
# /home/jovyan/work/data/landing/snapshot_2022-09-16.csv
# ingest data to bronce delta table
# recreate table
# delete data in landing zone
# prepare soda scan
#    version               timestamp userId userName operation  \
# 0        4 2022-08-21 16:47:53.032   None     None     WRITE
# 1        3 2022-08-21 16:47:16.839   None     None     WRITE
# 2        2 2022-08-21 16:46:45.546   None     None     WRITE
# 3        1 2022-08-21 16:46:14.282   None     None     WRITE
# 4        0 2022-08-21 16:45:23.128   None     None     WRITE
#
#                           operationParameters   job notebook clusterId  \
# 0  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 1  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 2  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 3  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 4  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
#
#    readVersion isolationLevel  isBlindAppend  \
# 0          3.0   Serializable          False
# 1          2.0   Serializable          False
# 2          1.0   Serializable          False
# 3          0.0   Serializable          False
# 4          NaN   Serializable          False
#
#                                     operationMetrics userMetadata  \
# 0  {'numOutputRows': '9', 'numOutputBytes': '5651...         None
# 1  {'numOutputRows': '7', 'numOutputBytes': '5246...         None
# 2  {'numOutputRows': '7', 'numOutputBytes': '3662...         None
# 3  {'numOutputRows': '6', 'numOutputBytes': '3561...         None
# 4  {'numOutputRows': '4', 'numOutputBytes': '3309...         None
#
#                             engineInfo
# 0  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 1  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 2  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 3  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 4  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# fake_now: 2022-09-24
# soda scan
# exit_code: 0
# build scan result
# store scan result
# /home/jovyan/work/data/bronze_scan_results/scan_results_4.json
# batch id : 6
# land file
# /home/jovyan/work/data/landing/snapshot_2022-09-23.csv
# ingest data to bronce delta table
# recreate table
# delete data in landing zone
# prepare soda scan
#    version               timestamp userId userName operation  \
# 0        5 2022-08-21 16:48:25.695   None     None     WRITE
# 1        4 2022-08-21 16:47:53.032   None     None     WRITE
# 2        3 2022-08-21 16:47:16.839   None     None     WRITE
# 3        2 2022-08-21 16:46:45.546   None     None     WRITE
# 4        1 2022-08-21 16:46:14.282   None     None     WRITE
# 5        0 2022-08-21 16:45:23.128   None     None     WRITE
#
#                           operationParameters   job notebook clusterId  \
# 0  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 1  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 2  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 3  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 4  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 5  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
#
#    readVersion isolationLevel  isBlindAppend  \
# 0          4.0   Serializable          False
# 1          3.0   Serializable          False
# 2          2.0   Serializable          False
# 3          1.0   Serializable          False
# 4          0.0   Serializable          False
# 5          NaN   Serializable          False
#
#                                     operationMetrics userMetadata  \
# 0  {'numOutputRows': '11', 'numOutputBytes': '584...         None
# 1  {'numOutputRows': '9', 'numOutputBytes': '5651...         None
# 2  {'numOutputRows': '7', 'numOutputBytes': '5246...         None
# 3  {'numOutputRows': '7', 'numOutputBytes': '3662...         None
# 4  {'numOutputRows': '6', 'numOutputBytes': '3561...         None
# 5  {'numOutputRows': '4', 'numOutputBytes': '3309...         None
#
#                             engineInfo
# 0  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 1  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 2  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 3  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 4  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 5  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# fake_now: 2022-10-03
# soda scan
# exit_code: 2
# build scan result
# store scan result
# /home/jovyan/work/data/bronze_scan_results/scan_results_5.json
# batch id : 7
# land file
# /home/jovyan/work/data/landing/snapshot_2022-09-30.csv
# ingest data to bronce delta table
# recreate table
# delete data in landing zone
# prepare soda scan
#    version               timestamp userId userName operation  \
# 0        6 2022-08-21 16:48:58.159   None     None     WRITE
# 1        5 2022-08-21 16:48:25.695   None     None     WRITE
# 2        4 2022-08-21 16:47:53.032   None     None     WRITE
# 3        3 2022-08-21 16:47:16.839   None     None     WRITE
# 4        2 2022-08-21 16:46:45.546   None     None     WRITE
# 5        1 2022-08-21 16:46:14.282   None     None     WRITE
# 6        0 2022-08-21 16:45:23.128   None     None     WRITE
#
#                           operationParameters   job notebook clusterId  \
# 0  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 1  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 2  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 3  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 4  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 5  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
# 6  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
#
#    readVersion isolationLevel  isBlindAppend  \
# 0          5.0   Serializable          False
# 1          4.0   Serializable          False
# 2          3.0   Serializable          False
# 3          2.0   Serializable          False
# 4          1.0   Serializable          False
# 5          0.0   Serializable          False
# 6          NaN   Serializable          False
#
#                                     operationMetrics userMetadata  \
# 0  {'numOutputRows': '14', 'numOutputBytes': '626...         None
# 1  {'numOutputRows': '11', 'numOutputBytes': '584...         None
# 2  {'numOutputRows': '9', 'numOutputBytes': '5651...         None
# 3  {'numOutputRows': '7', 'numOutputBytes': '5246...         None
# 4  {'numOutputRows': '7', 'numOutputBytes': '3662...         None
# 5  {'numOutputRows': '6', 'numOutputBytes': '3561...         None
# 6  {'numOutputRows': '4', 'numOutputBytes': '3309...         None
#
#                             engineInfo
# 0  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 1  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 2  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 3  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 4  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 5  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# 6  Apache-Spark/3.2.1 Delta-Lake/2.0.0
# fake_now: 2022-10-12
# soda scan
# exit_code: 2
# build scan result
# store scan result
# /home/jovyan/work/data/bronze_scan_results/scan_results_6.json

# %%
sdf_sr = spark.read.json(location_bronze_scan_results + f'/scan_results_*.json')
sdf_sr.toPandas()
# Out:
#   automatedMonitoringChecks  \
# 0                        []
# 1                        []
# 2                        []
# 3                        []
# 4                        []
# 5                        []
# 6                        []
#
#                                               checks  \
# 0  [(None, snapshot, checks for snapshot:\n  - sc...
# 1  [(None, snapshot, checks for snapshot:\n  - sc...
# 2  [(None, snapshot, checks for snapshot:\n  - sc...
# 3  [(None, snapshot, checks for snapshot:\n  - sc...
# 4  [(None, snapshot, checks for snapshot:\n  - sc...
# 5  [(None, snapshot, checks for snapshot:\n  - sc...
# 6  [(None, snapshot, checks for snapshot:\n  - sc...
#
#                dataTimestamp defaultDataSource definitionName  delta_version  \
# 0  2022-08-21T16:49:00+00:00          snapshot           None              6
# 1  2022-08-21T16:48:28+00:00          snapshot           None              5
# 2  2022-08-21T16:47:56+00:00          snapshot           None              4
# 3  2022-08-21T16:47:19+00:00          snapshot           None              3
# 4  2022-08-21T16:46:48+00:00          snapshot           None              2
# 5  2022-08-21T16:46:17+00:00          snapshot           None              1
# 6  2022-08-21T16:45:32+00:00          snapshot           None              0
#
#    hasErrors  hasFailures  hasWarnings  \
# 0      False         True        False
# 1      False         True        False
# 2      False        False        False
# 3      False        False        False
# 4      False        False        False
# 5      False        False        False
# 6      False        False        False
#
#                                                 logs  \
# 0  [(123, info, Soda Core 3.0.4, 2022-08-21T16:49...
# 1  [(96, info, Soda Core 3.0.4, 2022-08-21T16:48:...
# 2  [(77, info, Soda Core 3.0.4, 2022-08-21T16:47:...
# 3  [(58, info, Soda Core 3.0.4, 2022-08-21T16:47:...
# 4  [(39, info, Soda Core 3.0.4, 2022-08-21T16:46:...
# 5  [(20, info, Soda Core 3.0.4, 2022-08-21T16:46:...
# 6  [(1, info, Soda Core 3.0.4, 2022-08-21T16:45:3...
#
#                                             metadata  \
# 0  [(snapshot, 14, [Row(columnName='id', sourceDa...
# 1  [(snapshot, 11, [Row(columnName='id', sourceDa...
# 2  [(snapshot, 9, [Row(columnName='id', sourceDat...
# 3  [(snapshot, 7, [Row(columnName='id', sourceDat...
# 4  [(snapshot, 7, [Row(columnName='id', sourceDat...
# 5  [(snapshot, 6, [Row(columnName='id', sourceDat...
# 6  [(snapshot, 4, [Row(columnName='id', sourceDat...
#
#                                              metrics  \
# 0  [(None, None, metric-snapshot-snapshot-id-dupl...
# 1  [(None, None, metric-snapshot-snapshot-id-dupl...
# 2  [(None, None, metric-snapshot-snapshot-id-dupl...
# 3  [(None, None, metric-snapshot-snapshot-id-dupl...
# 4  [(None, None, metric-snapshot-snapshot-id-dupl...
# 5  [(None, None, metric-snapshot-snapshot-id-dupl...
# 6  [(None, None, metric-snapshot-snapshot-id-dupl...
#
#                                            profiling  \
# 0  [([Row(columnName='id', profile=Row(avg=10.5, ...
# 1  [([Row(columnName='id', profile=Row(avg=7.0, a...
# 2  [([Row(columnName='id', profile=Row(avg=5.7777...
# 3  [([Row(columnName='id', profile=Row(avg=4.4285...
# 4  [([Row(columnName='id', profile=Row(avg=4.1428...
# 5  [([Row(columnName='id', profile=Row(avg=2.5, a...
# 6  [([Row(columnName='id', profile=Row(avg=1.5, a...
#
#             scanEndTimestamp         scanStartTimestamp
# 0  2022-08-21T16:49:26+00:00  2022-08-21T16:49:00+00:00
# 1  2022-08-21T16:48:56+00:00  2022-08-21T16:48:28+00:00
# 2  2022-08-21T16:48:24+00:00  2022-08-21T16:47:56+00:00
# 3  2022-08-21T16:47:51+00:00  2022-08-21T16:47:19+00:00
# 4  2022-08-21T16:47:15+00:00  2022-08-21T16:46:48+00:00
# 5  2022-08-21T16:46:44+00:00  2022-08-21T16:46:17+00:00
# 6  2022-08-21T16:46:11+00:00  2022-08-21T16:45:32+00:00

# %%
sdf_sr.printSchema()
# Out:
# root
#  |-- automatedMonitoringChecks: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- checks: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- column: string (nullable = true)
#  |    |    |-- dataSource: string (nullable = true)
#  |    |    |-- definition: string (nullable = true)
#  |    |    |-- diagnostics: struct (nullable = true)
#  |    |    |    |-- fail: struct (nullable = true)
#  |    |    |    |    |-- greaterThan: double (nullable = true)
#  |    |    |    |    |-- lessThan: double (nullable = true)
#  |    |    |    |    |-- lessThanOrEqual: double (nullable = true)
#  |    |    |    |-- freshness: string (nullable = true)
#  |    |    |    |-- maxColumnTimestamp: string (nullable = true)
#  |    |    |    |-- maxColumnTimestampUtc: string (nullable = true)
#  |    |    |    |-- nowTimestamp: string (nullable = true)
#  |    |    |    |-- nowTimestampUtc: string (nullable = true)
#  |    |    |    |-- nowVariableName: string (nullable = true)
#  |    |    |    |-- schema: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- columnName: string (nullable = true)
#  |    |    |    |    |    |-- sourceDataType: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |    |-- identity: string (nullable = true)
#  |    |    |-- location: struct (nullable = true)
#  |    |    |    |-- col: long (nullable = true)
#  |    |    |    |-- filePath: string (nullable = true)
#  |    |    |    |-- line: long (nullable = true)
#  |    |    |-- metrics: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- outcome: string (nullable = true)
#  |    |    |-- table: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- dataTimestamp: string (nullable = true)
#  |-- defaultDataSource: string (nullable = true)
#  |-- definitionName: string (nullable = true)
#  |-- delta_version: long (nullable = true)
#  |-- hasErrors: boolean (nullable = true)
#  |-- hasFailures: boolean (nullable = true)
#  |-- hasWarnings: boolean (nullable = true)
#  |-- logs: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- index: long (nullable = true)
#  |    |    |-- level: string (nullable = true)
#  |    |    |-- message: string (nullable = true)
#  |    |    |-- timestamp: string (nullable = true)
#  |-- metadata: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- dataSource: string (nullable = true)
#  |    |    |-- rowCount: long (nullable = true)
#  |    |    |-- schema: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- columnName: string (nullable = true)
#  |    |    |    |    |-- sourceDataType: string (nullable = true)
#  |    |    |-- table: string (nullable = true)
#  |-- metrics: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- columnName: string (nullable = true)
#  |    |    |-- dataSourceName: string (nullable = true)
#  |    |    |-- identity: string (nullable = true)
#  |    |    |-- metricName: string (nullable = true)
#  |    |    |-- partitionName: string (nullable = true)
#  |    |    |-- tableName: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |-- profiling: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- columnProfiles: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- columnName: string (nullable = true)
#  |    |    |    |    |-- profile: struct (nullable = true)
#  |    |    |    |    |    |-- avg: double (nullable = true)
#  |    |    |    |    |    |-- avg_length: long (nullable = true)
#  |    |    |    |    |    |-- distinct: long (nullable = true)
#  |    |    |    |    |    |-- frequent_values: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- frequency: long (nullable = true)
#  |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |-- histogram: struct (nullable = true)
#  |    |    |    |    |    |    |-- boundaries: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |    |    |-- frequencies: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- max: double (nullable = true)
#  |    |    |    |    |    |-- max_length: long (nullable = true)
#  |    |    |    |    |    |-- maxs: array (nullable = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |    |-- min: double (nullable = true)
#  |    |    |    |    |    |-- min_length: long (nullable = true)
#  |    |    |    |    |    |-- mins: array (nullable = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |    |-- missing_count: long (nullable = true)
#  |    |    |    |    |    |-- stddev: double (nullable = true)
#  |    |    |    |    |    |-- sum: double (nullable = true)
#  |    |    |    |    |    |-- variance: double (nullable = true)
#  |    |    |-- dataSource: string (nullable = true)
#  |    |    |-- table: string (nullable = true)
#  |-- scanEndTimestamp: string (nullable = true)
#  |-- scanStartTimestamp: string (nullable = true)

# %% [markdown]
# ## Read scan results
#
# Helpful links
# * https://stackoverflow.com/questions/63838239/pyspark-dataframe-column-contains-array-of-dictionaries-want-to-make-each-key-f
# * https://stackoverflow.com/questions/49416637/access-dataframes-row-inside-row-nested-json-with-pyspark
#
# ### Checks
#
# #### Table checks

# %%
sdf_sr.select(
    sdf_sr.delta_version, 
    explode(sdf_sr.checks).alias("checks_ex")
).select('delta_version', 'checks_ex.*', 'checks_ex.diagnostics.value') \
.filter(F.col('column').isNull()).toPandas()
# Out:
#     delta_version column dataSource  \
# 0               6   None   snapshot
# 1               6   None   snapshot
# 2               5   None   snapshot
# 3               5   None   snapshot
# 4               4   None   snapshot
# 5               4   None   snapshot
# 6               3   None   snapshot
# 7               3   None   snapshot
# 8               2   None   snapshot
# 9               2   None   snapshot
# 10              1   None   snapshot
# 11              1   None   snapshot
# 12              0   None   snapshot
# 13              0   None   snapshot
#
#                                            definition  \
# 0   checks for snapshot:\n  - schema:\n      fail:...
# 1               checks for snapshot:\n  row_count > 0
# 2   checks for snapshot:\n  - schema:\n      fail:...
# 3               checks for snapshot:\n  row_count > 0
# 4   checks for snapshot:\n  - schema:\n      fail:...
# 5               checks for snapshot:\n  row_count > 0
# 6   checks for snapshot:\n  - schema:\n      fail:...
# 7               checks for snapshot:\n  row_count > 0
# 8   checks for snapshot:\n  - schema:\n      fail:...
# 9               checks for snapshot:\n  row_count > 0
# 10  checks for snapshot:\n  - schema:\n      fail:...
# 11              checks for snapshot:\n  row_count > 0
# 12  checks for snapshot:\n  - schema:\n      fail:...
# 13              checks for snapshot:\n  row_count > 0
#
#                                           diagnostics  identity  \
# 0   (None, None, None, None, None, None, None, [(i...  a9f97edf
# 1   ((None, None, 0.0), None, None, None, None, No...  0c97eed4
# 2   (None, None, None, None, None, None, None, [(i...  a9f97edf
# 3   ((None, None, 0.0), None, None, None, None, No...  0c97eed4
# 4   (None, None, None, None, None, None, None, [(i...  a9f97edf
# 5   ((None, None, 0.0), None, None, None, None, No...  0c97eed4
# 6   (None, None, None, None, None, None, None, [(i...  a9f97edf
# 7   ((None, None, 0.0), None, None, None, None, No...  0c97eed4
# 8   (None, None, None, None, None, None, None, [(i...  a9f97edf
# 9   ((None, None, 0.0), None, None, None, None, No...  0c97eed4
# 10  (None, None, None, None, None, None, None, [(i...  a9f97edf
# 11  ((None, None, 0.0), None, None, None, None, No...  0c97eed4
# 12  (None, None, None, None, None, None, None, [(i...  a9f97edf
# 13  ((None, None, 0.0), None, None, None, None, No...  0c97eed4
#
#                       location                               metrics  \
# 0    (5, sodacl_string.yml, 4)     [metric-snapshot-snapshot-schema]
# 1   (5, sodacl_string.yml, 11)  [metric-snapshot-snapshot-row_count]
# 2    (5, sodacl_string.yml, 4)     [metric-snapshot-snapshot-schema]
# 3   (5, sodacl_string.yml, 11)  [metric-snapshot-snapshot-row_count]
# 4    (5, sodacl_string.yml, 4)     [metric-snapshot-snapshot-schema]
# 5   (5, sodacl_string.yml, 11)  [metric-snapshot-snapshot-row_count]
# 6    (5, sodacl_string.yml, 4)     [metric-snapshot-snapshot-schema]
# 7   (5, sodacl_string.yml, 11)  [metric-snapshot-snapshot-row_count]
# 8    (5, sodacl_string.yml, 4)     [metric-snapshot-snapshot-schema]
# 9   (5, sodacl_string.yml, 11)  [metric-snapshot-snapshot-row_count]
# 10   (5, sodacl_string.yml, 4)     [metric-snapshot-snapshot-schema]
# 11  (5, sodacl_string.yml, 11)  [metric-snapshot-snapshot-row_count]
# 12   (5, sodacl_string.yml, 4)     [metric-snapshot-snapshot-schema]
# 13  (5, sodacl_string.yml, 11)  [metric-snapshot-snapshot-row_count]
#
#              name outcome     table             type  value
# 0    Schema Check    pass  snapshot           schema    NaN
# 1   row_count > 0    pass  snapshot  metricThreshold   14.0
# 2    Schema Check    pass  snapshot           schema    NaN
# 3   row_count > 0    pass  snapshot  metricThreshold   11.0
# 4    Schema Check    pass  snapshot           schema    NaN
# 5   row_count > 0    pass  snapshot  metricThreshold    9.0
# 6    Schema Check    pass  snapshot           schema    NaN
# 7   row_count > 0    pass  snapshot  metricThreshold    7.0
# 8    Schema Check    pass  snapshot           schema    NaN
# 9   row_count > 0    pass  snapshot  metricThreshold    7.0
# 10   Schema Check    pass  snapshot           schema    NaN
# 11  row_count > 0    pass  snapshot  metricThreshold    6.0
# 12   Schema Check    pass  snapshot           schema    NaN
# 13  row_count > 0    pass  snapshot  metricThreshold    4.0

# %% [markdown]
# #### All checks of particular column (here id)

# %%
sdf_sr.select(
    sdf_sr.delta_version, 
    explode(sdf_sr.checks).alias("checks_ex")
).select('delta_version', 'checks_ex.*', 'checks_ex.diagnostics.value') \
.filter(F.col('column') == 'id').toPandas()
# Out:
#     delta_version column dataSource  \
# 0               6     id   snapshot
# 1               6     id   snapshot
# 2               5     id   snapshot
# 3               5     id   snapshot
# 4               4     id   snapshot
# 5               4     id   snapshot
# 6               3     id   snapshot
# 7               3     id   snapshot
# 8               2     id   snapshot
# 9               2     id   snapshot
# 10              1     id   snapshot
# 11              1     id   snapshot
# 12              0     id   snapshot
# 13              0     id   snapshot
#
#                                          definition  \
# 0   checks for snapshot:\n  duplicate_count(id) = 0
# 1     checks for snapshot:\n  missing_count(id) = 0
# 2   checks for snapshot:\n  duplicate_count(id) = 0
# 3     checks for snapshot:\n  missing_count(id) = 0
# 4   checks for snapshot:\n  duplicate_count(id) = 0
# 5     checks for snapshot:\n  missing_count(id) = 0
# 6   checks for snapshot:\n  duplicate_count(id) = 0
# 7     checks for snapshot:\n  missing_count(id) = 0
# 8   checks for snapshot:\n  duplicate_count(id) = 0
# 9     checks for snapshot:\n  missing_count(id) = 0
# 10  checks for snapshot:\n  duplicate_count(id) = 0
# 11    checks for snapshot:\n  missing_count(id) = 0
# 12  checks for snapshot:\n  duplicate_count(id) = 0
# 13    checks for snapshot:\n  missing_count(id) = 0
#
#                                           diagnostics  identity  \
# 0   ((0.0, 0.0, None), None, None, None, None, Non...  6a2f657f
# 1   ((0.0, 0.0, None), None, None, None, None, Non...  33f7df58
# 2   ((0.0, 0.0, None), None, None, None, None, Non...  6a2f657f
# 3   ((0.0, 0.0, None), None, None, None, None, Non...  33f7df58
# 4   ((0.0, 0.0, None), None, None, None, None, Non...  6a2f657f
# 5   ((0.0, 0.0, None), None, None, None, None, Non...  33f7df58
# 6   ((0.0, 0.0, None), None, None, None, None, Non...  6a2f657f
# 7   ((0.0, 0.0, None), None, None, None, None, Non...  33f7df58
# 8   ((0.0, 0.0, None), None, None, None, None, Non...  6a2f657f
# 9   ((0.0, 0.0, None), None, None, None, None, Non...  33f7df58
# 10  ((0.0, 0.0, None), None, None, None, None, Non...  6a2f657f
# 11  ((0.0, 0.0, None), None, None, None, None, Non...  33f7df58
# 12  ((0.0, 0.0, None), None, None, None, None, Non...  6a2f657f
# 13  ((0.0, 0.0, None), None, None, None, None, Non...  33f7df58
#
#                       location                                        metrics  \
# 0   (5, sodacl_string.yml, 12)  [metric-snapshot-snapshot-id-duplicate_count]
# 1   (5, sodacl_string.yml, 14)    [metric-snapshot-snapshot-id-missing_count]
# 2   (5, sodacl_string.yml, 12)  [metric-snapshot-snapshot-id-duplicate_count]
# 3   (5, sodacl_string.yml, 14)    [metric-snapshot-snapshot-id-missing_count]
# 4   (5, sodacl_string.yml, 12)  [metric-snapshot-snapshot-id-duplicate_count]
# 5   (5, sodacl_string.yml, 14)    [metric-snapshot-snapshot-id-missing_count]
# 6   (5, sodacl_string.yml, 12)  [metric-snapshot-snapshot-id-duplicate_count]
# 7   (5, sodacl_string.yml, 14)    [metric-snapshot-snapshot-id-missing_count]
# 8   (5, sodacl_string.yml, 12)  [metric-snapshot-snapshot-id-duplicate_count]
# 9   (5, sodacl_string.yml, 14)    [metric-snapshot-snapshot-id-missing_count]
# 10  (5, sodacl_string.yml, 12)  [metric-snapshot-snapshot-id-duplicate_count]
# 11  (5, sodacl_string.yml, 14)    [metric-snapshot-snapshot-id-missing_count]
# 12  (5, sodacl_string.yml, 12)  [metric-snapshot-snapshot-id-duplicate_count]
# 13  (5, sodacl_string.yml, 14)    [metric-snapshot-snapshot-id-missing_count]
#
#                        name outcome     table             type  value
# 0   duplicate_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 1     missing_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 2   duplicate_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 3     missing_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 4   duplicate_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 5     missing_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 6   duplicate_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 7     missing_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 8   duplicate_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 9     missing_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 10  duplicate_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 11    missing_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 12  duplicate_count(id) = 0    pass  snapshot  metricThreshold    0.0
# 13    missing_count(id) = 0    pass  snapshot  metricThreshold    0.0

# %% [markdown]
# ### Metrics
# #### Table metrics

# %%
sdf_sr.select(
    sdf_sr.delta_version, 
    explode(sdf_sr.metrics).alias("metrics_ex")
).select('delta_version', 'metrics_ex.*') \
.filter(F.col('columnName').isNull()) \
.toPandas()
# Out:
#     delta_version columnName dataSourceName  \
# 0               6       None           None
# 1               6       None           None
# 2               6       None           None
# 3               6       None       snapshot
# 4               6       None           None
# ..            ...        ...            ...
# 58              0       None           None
# 59              0       None           None
# 60              0       None           None
# 61              0       None           None
# 62              0       None           None
#
#                                              identity       metricName  \
# 0         metric-snapshot-snapshot-id-duplicate_count  duplicate_count
# 1   metric-snapshot-snapshot-birthdate-invalid_cou...    invalid_count
# 2         metric-snapshot-snapshot-_delivery_date-max              max
# 3                     metric-snapshot-snapshot-schema           schema
# 4                  metric-snapshot-snapshot-row_count        row_count
# ..                                                ...              ...
# 58                 metric-snapshot-snapshot-row_count        row_count
# 59      metric-snapshot-snapshot-mail-duplicate_count  duplicate_count
# 60  metric-snapshot-snapshot-mail-invalid_count-61...    invalid_count
# 61  metric-snapshot-snapshot-birthdate-invalid_per...  invalid_percent
# 62          metric-snapshot-snapshot-id-missing_count    missing_count
#
#    partitionName tableName                                              value
# 0           None      None                                                  0
# 1           None      None                                                  0
# 2           None      None                          2022-09-30T00:00:00+00:00
# 3           None  snapshot  [{"columnName":"id","sourceDataType":"int"},{"...
# 4           None      None                                                 14
# ..           ...       ...                                                ...
# 58          None      None                                                  4
# 59          None      None                                                  0
# 60          None      None                                                  0
# 61          None      None                                                0.0
# 62          None      None                                                  0
#
# [63 rows x 8 columns]

# %% [markdown]
# #### All metrics of particular column

# %%
sdf_sr.select(
    sdf_sr.delta_version, 
    explode(sdf_sr.metrics).alias("metrics_ex")
).select('delta_version', 'metrics_ex.*') \
.filter(F.col('columnName') == 'id').toPandas()
# why is this empty ???
# Out:
# Empty DataFrame
# Columns: [delta_version, columnName, dataSourceName, identity, metricName, partitionName, tableName, value]
# Index: []

# %%
sdf_sr.select(
    sdf_sr.delta_version, 
    explode(sdf_sr.checks).alias("checks_ex")) \
.withColumn("checks_ex.diagnostics.value", F.col("checks_ex.diagnostics.value")) \
.withColumn("checks_ex.diagnostics.value", F.col("checks_ex.diagnostics.value")) \
.show()
# Out:
# +-------------+--------------------+---------------------------+
# |delta_version|           checks_ex|checks_ex.diagnostics.value|
# +-------------+--------------------+---------------------------+
# |            6|{null, snapshot, ...|                       null|
# |            6|{null, snapshot, ...|                       14.0|
# |            6|{_delivery_date, ...|                        0.0|
# |            6|{id, snapshot, ch...|                        0.0|
# |            6|{id, snapshot, ch...|                        0.0|
# |            6|{mail, snapshot, ...|                        0.0|
# |            6|{mail, snapshot, ...|                        0.0|
# |            6|{birthdate, snaps...|                        0.0|
# |            5|{null, snapshot, ...|                       null|
# |            5|{null, snapshot, ...|                       11.0|
# |            5|{_delivery_date, ...|                        0.0|
# |            5|{id, snapshot, ch...|                        0.0|
# |            5|{id, snapshot, ch...|                        0.0|
# |            5|{mail, snapshot, ...|                        0.0|
# |            5|{mail, snapshot, ...|                        0.0|
# |            5|{birthdate, snaps...|                        0.0|
# |            4|{null, snapshot, ...|                       null|
# |            4|{null, snapshot, ...|                        9.0|
# |            4|{_delivery_date, ...|                        0.0|
# |            4|{id, snapshot, ch...|                        0.0|
# +-------------+--------------------+---------------------------+
# only showing top 20 rows
