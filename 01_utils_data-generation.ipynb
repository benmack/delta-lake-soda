# %% [markdown]
# # utils - data generation

# %%
# %reload_ext autoreload
# %autoreload 2

from utils.data_generation import create_faker_profile_data
from utils.data_generation import FakerProfileDataSnapshot

create_faker_profile_data(3, None, 1)
# Out:
#                        job                     company          ssn  \
# 0               Contractor  Boone, Gallagher and Scott  508-98-7365
# 1  Rural practice surveyor                 Osborne PLC  861-51-6071
# 2    Aeronautical engineer               Hughes-Fisher  193-34-1782
#
#                                            residence  \
# 0  17066 Heather Grove Apt. 915\nNorth Anthonysid...
# 1     0499 Holland Extension\nNorth Kaylee, OH 30932
# 2                603 Ray Camp\nSouth Janet, NE 71896
#
#             current_location blood_group  \
# 0   (-31.8570425, 46.622110)          A+
# 1     (18.570026, 95.829061)         AB-
# 2  (-30.7832065, 158.643048)          O-
#
#                                              website     username  \
# 0  [https://hall.info/, https://www.monroe-hawkin...      paula86
# 1  [https://kelley.net/, http://www.herring-casti...  andreawhite
# 2  [http://johnston.com/, https://www.hutchinson....  icunningham
#
# ...

# %%
datagen = FakerProfileDataSnapshot(data_dir='data')
display(datagen.create_batch(1))
path_csv = datagen.land_batch(1)
print(path_csv)

path_csv = datagen.land_batch(2)
print(path_csv)
path_csv = datagen.land_batch(3)
print(path_csv)

# %ls data/landing
# Out:
#                        job                     company            name sex  \
# 0               Contractor  Boone, Gallagher and Scott  Misty Phillips   F
# 1  Rural practice surveyor                 Osborne PLC     Alfred Hall   M
# 2    Aeronautical engineer               Hughes-Fisher  Teresa Manning   F
# 3     Newspaper journalist                Gordon-Smith    Kyle Randall   M
#
#                                              address                   mail  \
# 0         4978 Chapman Bypass\nSanchezfurt, TN 23177        ana51@yahoo.com
# 1  11070 Wright Creek Apt. 541\nEast Jonathan, TN...      shawn57@yahoo.com
# 2         397 Maria Ways\nSouth Jamesville, OK 88863      fvargas@gmail.com
# 3      98150 Jones Way Apt. 251\nJonesside, OK 11215  michael49@hotmail.com
#
#     birthdate
# 0  1996-12-15
# 1  1922-02-28
# 2  1997-04-03
# 3  1922-03-06
# data/landing/snapshot_2022-08-19.csv
# data/landing/snapshot_2022-08-26.csv
# data/landing/snapshot_2022-09-02.csv
# ...
