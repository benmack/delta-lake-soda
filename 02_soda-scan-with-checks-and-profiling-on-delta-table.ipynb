# %% [markdown]
# # Soda scan with checks and profiling on delta table

# %% [markdown]
# ## Setup

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from pathlib import Path 
import pandas as pd
from utils.data_generation import FakerProfileDataSnapshot

from pyspark.sql import SparkSession
from  pyspark.sql.functions import input_file_name, split, regexp_extract

# %%
from delta import *

# %%
from pyspark.sql import SparkSession
from delta import *

builder = SparkSession.builder.appName("data-pipeline") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
# object for data generation
datagen = FakerProfileDataSnapshot(
    data_dir=str(Path('./data').resolve())
)
# clean landing storage
datagen.delete_batches_in_landing_dir()
print(datagen.bronze_dir)
datagen.delete_bronze_dir()
# Out:
# /home/jovyan/work/data/bronze

# %% [markdown]
# ## Parameters

# %%
read_csv_options = {'header': 'true', 'inferSchema': 'true', 'delimiter': ',', 'quote': '"', 'multiLine': 'true'}

# %%
location_landing = datagen.landing_dir
location_bronze = datagen.bronze_dir

# %% [markdown]
# ## Processing
#
# ### Generate data - CSV

# %%
path_csv = datagen.land_batch(7)
path_csv
# Out:
# '/home/jovyan/work/data/landing/snapshot_2022-09-30.csv'

# %% [markdown]
# ### Create delta table

# %%
df = spark.read.format('csv').options(**read_csv_options).load(str(path_csv)) \
    .withColumn("_delivery", regexp_extract(input_file_name(), '.*_(.*).csv$', 1))
df.toPandas()
# Out:
#     id                               job                       company  \
# 0    0                        Contractor    Boone, Gallagher and Scott
# 1    1           Rural practice surveyor                   Osborne PLC
# 2    3              Newspaper journalist                  Gordon-Smith
# 3    4               Programmer, systems            Rodriguez-Williams
# 4    6          Surveyor, rural practice                 Jackson-Davis
# 5    9  Surveyor, commercial/residential                   Kelly-Singh
# 6   12          Secondary school teacher                 Hernandez Ltd
# 7   13            Race relations officer     Jones, Randall and Cherry
# 8   14          Radiographer, diagnostic                 Baldwin Group
# 9   15            Geologist, engineering               Fernandez Group
# 10  16                Investment analyst                     Adams Inc
# 11  17          Museum education officer  Hoffman, Andrade and Stevens
# 12  18              Engineer, biomedical              Alexander-Weaver
# 13  19                       Pathologist                    Larson PLC
#
#             ssn                                            website  \
# 0   508-98-7365  ['https://hall.info/', 'https://www.monroe-haw...
# 1   861-51-6071  ['https://kelley.net/', 'http://www.herring-ca...
# 2   627-52-4610                        ['http://www.jackson.com/']
# 3   303-02-0239  ['https://www.pearson.com/', 'http://carlson.c...
# 4   498-01-2910    ['https://evans.info/', 'http://www.choi.com/']
# 5   402-72-6549  ['http://www.english.com/', 'https://wilson.co...
# 6   334-42-9390                             ['http://walker.biz/']
# 7   418-26-0136  ['https://turner-hunter.org/', 'http://www.fie...
# 8   412-92-6966  ['https://shah.net/', 'https://www.cohen-white...
# 9   308-98-1651  ['https://morgan.com/', 'https://www.gordon.co...
# 10  371-04-1284  ['https://www.turner.com/', 'http://www.merrit...
# 11  798-56-9807  ['http://www.hart.com/', 'http://www.edwards.c...
# 12  586-63-4366  ['https://www.lara.com/', 'https://www.hampton...
# 13  725-41-8761  ['https://cunningham-smith.com/', 'https://www...
#
#           username                name  \
# 0          paula86      Misty Phillips
# 1      andreawhite         Alfred Hall
# 2        matthew14        Kyle Randall
# 3           kdavis         Sally Davis
# 4   simpsonphillip          Keith Todd
# 5        rpeterson       Kelsey Ramsey
# 6       harriscarl  Veronica Maldonado
# 7          hbryant         Samuel Mack
# 8        gphillips         Anita Price
# 9         robert00   Courtney Gonzalez
# 10  mcintyredonald       Jill Anderson
# 11    hesterandrew          Lori Kline
# 12      lauraboyle     Alison Robinson
# 13  johnsonrichard    Taylor Hernandez
#
#                                               address  \
# 0          4978 Chapman Bypass\nSanchezfurt, TN 23177
# 1   11070 Wright Creek Apt. 541\nEast Jonathan, TN...
# 2       98150 Jones Way Apt. 251\nJonesside, OK 11215
# 3            4052 Sparks Prairie\nJohnville, RI 76389
# 4   280 Lindsey Road Apt. 412\nSouth Melissabury, ...
# 5       36377 Christensen Fort\nPort Justin, OR 51565
# 6          32860 Yoder Oval\nJeffreyborough, NM 31331
# 7        2024 Hodge Radial\nStefaniechester, NY 38154
# 8   97126 Gary Glens Suite 847\nPort Katherine, NM...
# 9            34549 Johnson Isle\nDonaldview, WI 19280
# 10         5542 Melinda Light\nSullivanberg, LA 87910
# 11                   PSC 6263, Box 1355\nAPO AP 32636
# 12         67190 Davis Court\nWilliamshaven, WI 02095
# 13            928 Sara Vista\nTaylorborough, VA 52559
#
#                          mail   birthdate   _delivery
# 0             ana51@yahoo.com  1996-12-15  2022-09-30
# 1           shawn57@yahoo.com  1922-02-28  2022-09-30
# 2       michael49@hotmail.com  1922-03-06  2022-09-30
# 3     sanchezandrew@gmail.com  1961-04-20  2022-09-30
# 4           umartin@yahoo.com  1923-10-24  2022-09-30
# 5      shannonscott@yahoo.com  1987-05-30  2022-09-30
# 6         xchavez@hotmail.com  1932-04-26  2022-09-30
# 7          bvazquez@yahoo.com  2012-05-14  2022-09-30
# 8       toddjessica@yahoo.com  2003-02-01  2022-09-30
# 9   reedchristopher@gmail.com  1947-06-13  2022-09-30
# 10     medinaalec@hotmail.com  1924-08-30  2022-09-30
# 11            xpaul@yahoo.com  1995-04-12  2022-09-30
# 12       moseslarry@yahoo.com  2005-01-04  2022-09-30
# 13        kaitlyn23@yahoo.com  2003-02-28  2022-09-30

# %%
df.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').save(location_bronze)

# %%
spark.sql('DROP TABLE IF EXISTS snapshot')
spark.sql(f'CREATE TABLE IF NOT EXISTS snapshot USING DELTA LOCATION "{location_bronze}"')
# Out:
# DataFrame[]

# %%
spark.sql(f'DESCRIBE HISTORY snapshot').toPandas()
# Out:
#    version               timestamp userId userName operation  \
# 0        0 2022-08-15 19:12:32.553   None     None     WRITE
#
#                           operationParameters   job notebook clusterId  \
# 0  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
#
#    readVersion isolationLevel  isBlindAppend  \
# 0          NaN   Serializable          False
#
#                                     operationMetrics userMetadata  \
# 0  {'numOutputRows': '14', 'numOutputBytes': '628...         None
#
#                             engineInfo
# 0  Apache-Spark/3.2.1 Delta-Lake/2.0.0

# %% [markdown]
# ### Run soda scan
#
# ... with checks, discovery, profiling.

# %%
from soda.scan import Scan

scan = Scan()
scan.disable_telemetry()
scan.set_data_source_name('snapshot')
scan.add_spark_session(spark, 'snapshot')

scan.add_sodacl_yaml_str('''
checks for snapshot:
  - row_count = 13
  - duplicate_count(id, mail) = 0
  - missing_count(id, mail) = 0
  - invalid_count(mail) = 0:
      valid format: email
  - invalid_percent(ssn, birthdate) = 0:
      valid length: 10
discover tables:
  tables:
    - include snapshot
profile columns:
  columns:
    - snapshot.%
''')
# scan.set_verbose() # ?
exit_code = scan.execute()
exit_code
# Out:
# root
#  |-- count(1): long (nullable = false)
#  |-- count(CASE WHEN (id IS NULL) THEN 1 END): long (nullable = false)
#  |-- count(CASE WHEN ((NOT (mail IS NULL)) AND (NOT RLIKE(mail, ^[a-zA-ZÀ-ÿĀ-ſƀ-ȳ0-9.\-_%]+@[a-zA-ZÀ-ÿĀ-ſƀ-ȳ0-9.\-_%]+\.[A-Za-z]{2,4}$))) THEN 1 END): long (nullable = false)
#  |-- count(1): long (nullable = false)
#  |-- count(CASE WHEN ((NOT (ssn IS NULL)) AND (NOT (length(ssn) = 10))) THEN 1 END): long (nullable = false)
#
# +--------+----------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------+--------+------------------------------------------------------------------------------+
# |count(1)|count(CASE WHEN (id IS NULL) THEN 1 END)|count(CASE WHEN ((NOT (mail IS NULL)) AND (NOT RLIKE(mail, ^[a-zA-ZÀ-ÿĀ-ſƀ-ȳ0-9.\-_%]+@[a-zA-ZÀ-ÿĀ-ſƀ-ȳ0-9.\-_%]+\.[A-Za-z]{2,4}$))) THEN 1 END)|count(1)|count(CASE WHEN ((NOT (ssn IS NULL)) AND (NOT (length(ssn) = 10))) THEN 1 END)|
# +--------+----------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------+--------+------------------------------------------------------------------------------+
# |      14|                                       0|                                                                                                                                               0|      14|                                                                            14|
# +--------+----------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------+--------+------------------------------------------------------------------------------+
#
# root
#  |-- id: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- company: string (nullable = true)
#  |-- ssn: string (nullable = true)
#  |-- website: string (nullable = true)
#  |-- username: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- mail: string (nullable = true)
#  |-- birthdate: string (nullable = true)
#  |-- _delivery: string (nullable = true)
#
# +---+--------------------+--------------------+-----------+--------------------+--------------+------------------+--------------------+--------------------+----------+----------+
# | id|                 job|             company|        ssn|             website|      username|              name|             address|                mail| birthdate| _delivery|
# +---+--------------------+--------------------+-----------+--------------------+--------------+------------------+--------------------+--------------------+----------+----------+
# |  0|          Contractor|Boone, Gallagher ...|508-98-7365|['https://hall.in...|       paula86|    Misty Phillips|4978 Chapman Bypa...|     ana51@yahoo.com|1996-12-15|2022-09-30|
# |  1|Rural practice su...|         Osborne PLC|861-51-6071|['https://kelley....|   andreawhite|       Alfred Hall|11070 Wright Cree...|   shawn57@yahoo.com|1922-02-28|2022-09-30|
# |  3|Newspaper journalist|        Gordon-Smith|627-52-4610|['http://www.jack...|     matthew14|      Kyle Randall|98150 Jones Way A...|michael49@hotmail...|1922-03-06|2022-09-30|
# |  4| Programmer, systems|  Rodriguez-Williams|303-02-0239|['https://www.pea...|        kdavis|       Sally Davis|4052 Sparks Prair...|sanchezandrew@gma...|1961-04-20|2022-09-30|
# |  6|Surveyor, rural p...|       Jackson-Davis|498-01-2910|['https://evans.i...|simpsonphillip|        Keith Todd|280 Lindsey Road ...|   umartin@yahoo.com|1923-10-24|2022-09-30|
# |  9|Surveyor, commerc...|         Kelly-Singh|402-72-6549|['http://www.engl...|     rpeterson|     Kelsey Ramsey|36377 Christensen...|shannonscott@yaho...|1987-05-30|2022-09-30|
# | 12|Secondary school ...|       Hernandez Ltd|334-42-9390|['http://walker.b...|    harriscarl|Veronica Maldonado|32860 Yoder Oval\...| xchavez@hotmail.com|1932-04-26|2022-09-30|
# | 13|Race relations of...|Jones, Randall an...|418-26-0136|['https://turner-...|       hbryant|       Samuel Mack|2024 Hodge Radial...|  bvazquez@yahoo.com|2012-05-14|2022-09-30|
# | 14|Radiographer, dia...|       Baldwin Group|412-92-6966|['https://shah.ne...|     gphillips|       Anita Price|97126 Gary Glens ...|toddjessica@yahoo...|2003-02-01|2022-09-30|
# | 15|Geologist, engine...|     Fernandez Group|308-98-1651|['https://morgan....|      robert00| Courtney Gonzalez|34549 Johnson Isl...|reedchristopher@g...|1947-06-13|2022-09-30|
# | 16|  Investment analyst|           Adams Inc|371-04-1284|['https://www.tur...|mcintyredonald|     Jill Anderson|5542 Melinda Ligh...|medinaalec@hotmai...|1924-08-30|2022-09-30|
# | 17|Museum education ...|Hoffman, Andrade ...|798-56-9807|['http://www.hart...|  hesterandrew|        Lori Kline|PSC 6263, Box 135...|     xpaul@yahoo.com|1995-04-12|2022-09-30|
# | 18|Engineer, biomedical|    Alexander-Weaver|586-63-4366|['https://www.lar...|    lauraboyle|   Alison Robinson|67190 Davis Court...|moseslarry@yahoo.com|2005-01-04|2022-09-30|
# | 19|         Pathologist|          Larson PLC|725-41-8761|['https://cunning...|johnsonrichard|  Taylor Hernandez|928 Sara Vista\nT...| kaitlyn23@yahoo.com|2003-02-28|2022-09-30|
# +---+--------------------+--------------------+-----------+--------------------+--------------+------------------+--------------------+--------------------+----------+----------+
#
# root
#  |-- id: integer (nullable = true)
#  |-- mail: string (nullable = true)
#  |-- frequency: long (nullable = false)
#
# +---+----+---------+
# | id|mail|frequency|
# +---+----+---------+
# +---+----+---------+
#
# root
#  |-- namespace: string (nullable = false)
#  |-- tableName: string (nullable = false)
#  |-- isTemporary: boolean (nullable = false)
#
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |  default| snapshot|      false|
# +---------+---------+-----------+
#
# root
#  |-- count(1): long (nullable = false)
#
# +--------+
# |count(1)|
# +--------+
# |      14|
# +--------+
#
# root
#  |-- col_name: string (nullable = false)
#  |-- data_type: string (nullable = false)
#  |-- comment: string (nullable = true)
#
# +---------------+---------+-------+
# |       col_name|data_type|comment|
# +---------------+---------+-------+
# |             id|      int|       |
# |            job|   string|       |
# |        company|   string|       |
# |            ssn|   string|       |
# |        website|   string|       |
# |       username|   string|       |
# |           name|   string|       |
# |        address|   string|       |
# |           mail|   string|       |
# |      birthdate|   string|       |
# |      _delivery|   string|       |
# |               |         |       |
# | # Partitioning|         |       |
# |Not partitioned|         |       |
# +---------------+---------+-------+
#
# root
#  |-- namespace: string (nullable = false)
#  |-- tableName: string (nullable = false)
#  |-- isTemporary: boolean (nullable = false)
#
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |  default| snapshot|      false|
# +---------+---------+-----------+
#
# root
#  |-- col_name: string (nullable = false)
#  |-- data_type: string (nullable = false)
#  |-- comment: string (nullable = true)
#
# +---------------+---------+-------+
# |       col_name|data_type|comment|
# +---------------+---------+-------+
# |             id|      int|       |
# |            job|   string|       |
# |        company|   string|       |
# |            ssn|   string|       |
# |        website|   string|       |
# |       username|   string|       |
# |           name|   string|       |
# |        address|   string|       |
# |           mail|   string|       |
# |      birthdate|   string|       |
# |      _delivery|   string|       |
# |               |         |       |
# | # Partitioning|         |       |
# |Not partitioned|         |       |
# +---------------+---------+-------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: integer (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+------+----------+
# |        metric_|index_|value_|frequency_|
# +---------------+------+------+----------+
# |frequent_values|     1|    12|         1|
# |frequent_values|     2|     1|         1|
# |frequent_values|     3|    13|         1|
# |frequent_values|     4|     6|         1|
# |frequent_values|     5|    16|         1|
# |frequent_values|     6|     3|         1|
# |frequent_values|     7|    19|         1|
# |frequent_values|     8|    15|         1|
# |frequent_values|     9|     9|         1|
# |frequent_values|    10|    17|         1|
# |           maxs|     1|    19|         1|
# |           maxs|     2|    18|         1|
# |           maxs|     3|    17|         1|
# |           maxs|     4|    16|         1|
# |           maxs|     5|    15|         1|
# |           mins|     1|     0|         1|
# |           mins|     2|     1|         1|
# |           mins|     3|     3|         1|
# |           mins|     4|     4|         1|
# |           mins|     5|     6|         1|
# +---------------+------+------+----------+
#
# root
#  |-- average: double (nullable = true)
#  |-- sum: long (nullable = true)
#  |-- variance: double (nullable = true)
#  |-- standard_deviation: double (nullable = true)
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#
# +-------+---+-----------------+------------------+---------------+--------------+
# |average|sum|         variance|standard_deviation|distinct_values|missing_values|
# +-------+---+-----------------+------------------+---------------+--------------+
# |   10.5|147|43.34615384615384| 6.583779601881721|             14|             0|
# +-------+---+-----------------+------------------+---------------+--------------+
#
# root
#  |-- sum(CASE WHEN (value_ < 2) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((2 <= value_) AND (value_ < 3)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((3 <= value_) AND (value_ < 5)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((5 <= value_) AND (value_ < 6)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((6 <= value_) AND (value_ < 8)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((8 <= value_) AND (value_ < 9)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((9 <= value_) AND (value_ < 11)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((11 <= value_) AND (value_ < 12)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((12 <= value_) AND (value_ < 14)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((14 <= value_) AND (value_ < 15)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((15 <= value_) AND (value_ < 17)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((17 <= value_) AND (value_ < 18)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN ((18 <= value_) AND (value_ < 19)) THEN frequency_ END): long (nullable = true)
#  |-- sum(CASE WHEN (19 <= value_) THEN frequency_ END): long (nullable = true)
#
# +-----------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+--------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+-------------------------------------------------+
# |sum(CASE WHEN (value_ < 2) THEN frequency_ END)|sum(CASE WHEN ((2 <= value_) AND (value_ < 3)) THEN frequency_ END)|sum(CASE WHEN ((3 <= value_) AND (value_ < 5)) THEN frequency_ END)|sum(CASE WHEN ((5 <= value_) AND (value_ < 6)) THEN frequency_ END)|sum(CASE WHEN ((6 <= value_) AND (value_ < 8)) THEN frequency_ END)|sum(CASE WHEN ((8 <= value_) AND (value_ < 9)) THEN frequency_ END)|sum(CASE WHEN ((9 <= value_) AND (value_ < 11)) THEN frequency_ END)|sum(CASE WHEN ((11 <= value_) AND (value_ < 12)) THEN frequency_ END)|sum(CASE WHEN ((12 <= value_) AND (value_ < 14)) THEN frequency_ END)|sum(CASE WHEN ((14 <= value_) AND (value_ < 15)) THEN frequency_ END)|sum(CASE WHEN ((15 <= value_) AND (value_ < 17)) THEN frequency_ END)|sum(CASE WHEN ((17 <= value_) AND (value_ < 18)) THEN frequency_ END)|sum(CASE WHEN ((18 <= value_) AND (value_ < 19)) THEN frequency_ END)|sum(CASE WHEN (19 <= value_) THEN frequency_ END)|
# +-----------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+--------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+-------------------------------------------------+
# |                                              2|                                                               null|                                                                  2|                                                               null|                                                                  1|                                                               null|                                                                   1|                                                                 null|                                                                    2|                                                                    1|                                                                    2|                                                                    1|                                                                    1|                                                1|
# +-----------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------+--------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+---------------------------------------------------------------------+-------------------------------------------------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+--------------------+----------+
# |        metric_|index_|              value_|frequency_|
# +---------------+------+--------------------+----------+
# |frequent_values|     1|          Contractor|         1|
# |frequent_values|     2|Rural practice su...|         1|
# |frequent_values|     3|Museum education ...|         1|
# |frequent_values|     4|Secondary school ...|         1|
# |frequent_values|     5|         Pathologist|         1|
# |frequent_values|     6|Race relations of...|         1|
# |frequent_values|     7|Surveyor, rural p...|         1|
# |frequent_values|     8|Newspaper journalist|         1|
# |frequent_values|     9|Surveyor, commerc...|         1|
# |frequent_values|    10|Geologist, engine...|         1|
# +---------------+------+--------------------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+------------------+----------+----------+
# |distinct_values|missing_values|        avg_length|min_length|max_length|
# +---------------+--------------+------------------+----------+----------+
# |             14|             0|20.928571428571427|        10|        32|
# +---------------+--------------+------------------+----------+----------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+--------------------+----------+
# |        metric_|index_|              value_|frequency_|
# +---------------+------+--------------------+----------+
# |frequent_values|     1|       Hernandez Ltd|         1|
# |frequent_values|     2|        Gordon-Smith|         1|
# |frequent_values|     3|       Baldwin Group|         1|
# |frequent_values|     4|  Rodriguez-Williams|         1|
# |frequent_values|     5|    Alexander-Weaver|         1|
# |frequent_values|     6|Boone, Gallagher ...|         1|
# |frequent_values|     7|         Kelly-Singh|         1|
# |frequent_values|     8|         Osborne PLC|         1|
# |frequent_values|     9|       Jackson-Davis|         1|
# |frequent_values|    10|          Larson PLC|         1|
# +---------------+------+--------------------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+------------------+----------+----------+
# |distinct_values|missing_values|        avg_length|min_length|max_length|
# +---------------+--------------+------------------+----------+----------+
# |             14|             0|15.714285714285714|         9|        28|
# +---------------+--------------+------------------+----------+----------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+-----------+----------+
# |        metric_|index_|     value_|frequency_|
# +---------------+------+-----------+----------+
# |frequent_values|     1|861-51-6071|         1|
# |frequent_values|     2|586-63-4366|         1|
# |frequent_values|     3|798-56-9807|         1|
# |frequent_values|     4|412-92-6966|         1|
# |frequent_values|     5|508-98-7365|         1|
# |frequent_values|     6|418-26-0136|         1|
# |frequent_values|     7|402-72-6549|         1|
# |frequent_values|     8|627-52-4610|         1|
# |frequent_values|     9|498-01-2910|         1|
# |frequent_values|    10|308-98-1651|         1|
# +---------------+------+-----------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+----------+----------+----------+
# |distinct_values|missing_values|avg_length|min_length|max_length|
# +---------------+--------------+----------+----------+----------+
# |             14|             0|      11.0|        11|        11|
# +---------------+--------------+----------+----------+----------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+--------------------+----------+
# |        metric_|index_|              value_|frequency_|
# +---------------+------+--------------------+----------+
# |frequent_values|     1|['https://evans.i...|         1|
# |frequent_values|     2|['https://turner-...|         1|
# |frequent_values|     3|['http://www.hart...|         1|
# |frequent_values|     4|['https://www.lar...|         1|
# |frequent_values|     5|['http://www.engl...|         1|
# |frequent_values|     6|['http://www.jack...|         1|
# |frequent_values|     7|['https://www.pea...|         1|
# |frequent_values|     8|['https://morgan....|         1|
# |frequent_values|     9|['https://www.tur...|         1|
# |frequent_values|    10|['https://shah.ne...|         1|
# +---------------+------+--------------------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+-----------------+----------+----------+
# |distinct_values|missing_values|       avg_length|min_length|max_length|
# +---------------+--------------+-----------------+----------+----------+
# |             14|             0|74.64285714285714|        22|       116|
# +---------------+--------------+-----------------+----------+----------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+--------------+----------+
# |        metric_|index_|        value_|frequency_|
# +---------------+------+--------------+----------+
# |frequent_values|     1|    lauraboyle|         1|
# |frequent_values|     2|       hbryant|         1|
# |frequent_values|     3|  hesterandrew|         1|
# |frequent_values|     4|     gphillips|         1|
# |frequent_values|     5|     matthew14|         1|
# |frequent_values|     6|johnsonrichard|         1|
# |frequent_values|     7|     rpeterson|         1|
# |frequent_values|     8|   andreawhite|         1|
# |frequent_values|     9|    harriscarl|         1|
# |frequent_values|    10|        kdavis|         1|
# +---------------+------+--------------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+----------+----------+----------+
# |distinct_values|missing_values|avg_length|min_length|max_length|
# +---------------+--------------+----------+----------+----------+
# |             14|             0|      10.0|         6|        14|
# +---------------+--------------+----------+----------+----------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+------------------+----------+
# |        metric_|index_|            value_|frequency_|
# +---------------+------+------------------+----------+
# |frequent_values|     1|        Lori Kline|         1|
# |frequent_values|     2|       Samuel Mack|         1|
# |frequent_values|     3|    Misty Phillips|         1|
# |frequent_values|     4| Courtney Gonzalez|         1|
# |frequent_values|     5|Veronica Maldonado|         1|
# |frequent_values|     6|        Keith Todd|         1|
# |frequent_values|     7|       Sally Davis|         1|
# |frequent_values|     8|     Jill Anderson|         1|
# |frequent_values|     9|     Kelsey Ramsey|         1|
# |frequent_values|    10|       Alfred Hall|         1|
# +---------------+------+------------------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+----------+----------+----------+
# |distinct_values|missing_values|avg_length|min_length|max_length|
# +---------------+--------------+----------+----------+----------+
# |             14|             0|      13.0|        10|        18|
# +---------------+--------------+----------+----------+----------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+--------------------+----------+
# |        metric_|index_|              value_|frequency_|
# +---------------+------+--------------------+----------+
# |frequent_values|     1|4978 Chapman Bypa...|         1|
# |frequent_values|     2|98150 Jones Way A...|         1|
# |frequent_values|     3|32860 Yoder Oval\...|         1|
# |frequent_values|     4|PSC 6263, Box 135...|         1|
# |frequent_values|     5|2024 Hodge Radial...|         1|
# |frequent_values|     6|97126 Gary Glens ...|         1|
# |frequent_values|     7|36377 Christensen...|         1|
# |frequent_values|     8|67190 Davis Court...|         1|
# |frequent_values|     9|928 Sara Vista\nT...|         1|
# |frequent_values|    10|280 Lindsey Road ...|         1|
# +---------------+------+--------------------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+------------------+----------+----------+
# |distinct_values|missing_values|        avg_length|min_length|max_length|
# +---------------+--------------+------------------+----------+----------+
# |             14|             0|42.642857142857146|        31|        53|
# +---------------+--------------+------------------+----------+----------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+--------------------+----------+
# |        metric_|index_|              value_|frequency_|
# +---------------+------+--------------------+----------+
# |frequent_values|     1|     ana51@yahoo.com|         1|
# |frequent_values|     2|moseslarry@yahoo.com|         1|
# |frequent_values|     3| xchavez@hotmail.com|         1|
# |frequent_values|     4|reedchristopher@g...|         1|
# |frequent_values|     5|   shawn57@yahoo.com|         1|
# |frequent_values|     6| kaitlyn23@yahoo.com|         1|
# |frequent_values|     7|shannonscott@yaho...|         1|
# |frequent_values|     8|michael49@hotmail...|         1|
# |frequent_values|     9|sanchezandrew@gma...|         1|
# |frequent_values|    10|     xpaul@yahoo.com|         1|
# +---------------+------+--------------------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+------------------+----------+----------+
# |distinct_values|missing_values|        avg_length|min_length|max_length|
# +---------------+--------------+------------------+----------+----------+
# |             14|             0|19.571428571428573|        15|        25|
# +---------------+--------------+------------------+----------+----------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+----------+----------+
# |        metric_|index_|    value_|frequency_|
# +---------------+------+----------+----------+
# |frequent_values|     1|1922-03-06|         1|
# |frequent_values|     2|1922-02-28|         1|
# |frequent_values|     3|1947-06-13|         1|
# |frequent_values|     4|1924-08-30|         1|
# |frequent_values|     5|2003-02-01|         1|
# |frequent_values|     6|2012-05-14|         1|
# |frequent_values|     7|1995-04-12|         1|
# |frequent_values|     8|1961-04-20|         1|
# |frequent_values|     9|1923-10-24|         1|
# |frequent_values|    10|2003-02-28|         1|
# +---------------+------+----------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+----------+----------+----------+
# |distinct_values|missing_values|avg_length|min_length|max_length|
# +---------------+--------------+----------+----------+----------+
# |             14|             0|      10.0|        10|        10|
# +---------------+--------------+----------+----------+----------+
#
# root
#  |-- metric_: string (nullable = false)
#  |-- index_: integer (nullable = false)
#  |-- value_: string (nullable = true)
#  |-- frequency_: long (nullable = false)
#
# +---------------+------+----------+----------+
# |        metric_|index_|    value_|frequency_|
# +---------------+------+----------+----------+
# |frequent_values|     1|2022-09-30|        14|
# +---------------+------+----------+----------+
#
# root
#  |-- distinct_values: long (nullable = false)
#  |-- missing_values: long (nullable = true)
#  |-- avg_length: double (nullable = true)
#  |-- min_length: integer (nullable = true)
#  |-- max_length: integer (nullable = true)
#
# +---------------+--------------+----------+----------+----------+
# |distinct_values|missing_values|avg_length|min_length|max_length|
# +---------------+--------------+----------+----------+----------+
# |              1|             0|      10.0|        10|        10|
# +---------------+--------------+----------+----------+----------+
# 2

# %% [markdown]
# ### Store soda scan results to delta table

# %%
for ele in scan._checks:
    print(ele.get_cloud_dict())
pd.DataFrame([ele.get_cloud_dict() for ele in scan._checks])
# Out:
# {'identity': '27c242a2', 'name': 'row_count = 13', 'type': 'metricThreshold', 'definition': 'checks for snapshot:\n  row_count = 13', 'location': {'filePath': 'sodacl_string.yml', 'line': 3, 'col': 5}, 'dataSource': 'snapshot', 'table': 'snapshot', 'column': None, 'metrics': ['metric-snapshot-snapshot-row_count'], 'outcome': 'fail', 'diagnostics': {'value': 14, 'fail': {'greaterThan': 13.0, 'lessThan': 13.0}}}
# {'identity': '9027c3d2', 'name': 'duplicate_count(id, mail) = 0', 'type': 'metricThreshold', 'definition': 'checks for snapshot:\n  duplicate_count(id, mail) = 0', 'location': {'filePath': 'sodacl_string.yml', 'line': 4, 'col': 5}, 'dataSource': 'snapshot', 'table': 'snapshot', 'column': None, 'metrics': ['metric-snapshot-snapshot-duplicate_count-248c8fa3'], 'outcome': 'pass', 'diagnostics': {'value': 0, 'fail': {'greaterThan': 0.0, 'lessThan': 0.0}}}
# {'identity': 'c322a794', 'name': 'missing_count(id, mail) = 0', 'type': 'metricThreshold', 'definition': 'checks for snapshot:\n  missing_count(id, mail) = 0', 'location': {'filePath': 'sodacl_string.yml', 'line': 5, 'col': 5}, 'dataSource': 'snapshot', 'table': 'snapshot', 'column': 'id', 'metrics': ['metric-snapshot-snapshot-id-missing_count-248c8fa3'], 'outcome': 'pass', 'diagnostics': {'value': 0, 'fail': {'greaterThan': 0.0, 'lessThan': 0.0}}}
# {'identity': '55ab369a', 'name': 'invalid_count(mail) = 0', 'type': 'metricThreshold', 'definition': 'checks for snapshot:\n  - invalid_count(mail) = 0:\n      valid format: email\n', 'location': {'filePath': 'sodacl_string.yml', 'line': 6, 'col': 5}, 'dataSource': 'snapshot', 'table': 'snapshot', 'column': 'mail', 'metrics': ['metric-snapshot-snapshot-mail-invalid_count-61813b33'], 'outcome': 'pass', 'diagnostics': {'value': 0, 'fail': {'greaterThan': 0.0, 'lessThan': 0.0}}}
# {'identity': '2b0efc8f', 'name': 'invalid_percent(ssn, birthdate) = 0', 'type': 'metricThreshold', 'definition': 'checks for snapshot:\n  - invalid_percent(ssn, birthdate) = 0:\n      valid length: 10\n', 'location': {'filePath': 'sodacl_string.yml', 'line': 8, 'col': 5}, 'dataSource': 'snapshot', 'table': 'snapshot', 'column': 'ssn', 'metrics': ['metric-snapshot-snapshot-ssn-invalid_percent-3a74e0ac'], 'outcome': 'fail', 'diagnostics': {'value': 100.0, 'fail': {'greaterThan': 0.0, 'lessThan': 0.0}, 'failedRowsFile': {'columns': [{'name': 'id', 'type': 'IntegerType'}, {'name': 'job', 'type': 'StringType'}, {'name': 'company', 'type': 'StringType'}, {'name': 'ssn', 'type': 'StringType'}, {'name': 'website', 'type': 'StringType'}, {'name': 'username', 'type': 'StringType'}, {'name': 'name', 'type': 'StringType'}, {'name': 'address', 'type': 'StringType'}, {'name': 'mail', 'type': 'StringType'}, {'name': 'birthdate', 'type': 'StringType'}, {'name': '_delivery', 'type': 'StringType'}], 'totalRowCount': 14, 'storedRowCount': 14}}}
#    identity                                 name             type  \
# 0  27c242a2                       row_count = 13  metricThreshold
# 1  9027c3d2        duplicate_count(id, mail) = 0  metricThreshold
# 2  c322a794          missing_count(id, mail) = 0  metricThreshold
# 3  55ab369a              invalid_count(mail) = 0  metricThreshold
# 4  2b0efc8f  invalid_percent(ssn, birthdate) = 0  metricThreshold
#
#                                           definition  \
# 0             checks for snapshot:\n  row_count = 13
# 1  checks for snapshot:\n  duplicate_count(id, ma...
# 2  checks for snapshot:\n  missing_count(id, mail...
# 3  checks for snapshot:\n  - invalid_count(mail) ...
# 4  checks for snapshot:\n  - invalid_percent(ssn,...
#
#                                             location dataSource     table  \
# 0  {'filePath': 'sodacl_string.yml', 'line': 3, '...   snapshot  snapshot
# 1  {'filePath': 'sodacl_string.yml', 'line': 4, '...   snapshot  snapshot
# 2  {'filePath': 'sodacl_string.yml', 'line': 5, '...   snapshot  snapshot
# 3  {'filePath': 'sodacl_string.yml', 'line': 6, '...   snapshot  snapshot
# 4  {'filePath': 'sodacl_string.yml', 'line': 8, '...   snapshot  snapshot
#
#   column                                            metrics outcome  \
# 0   None               [metric-snapshot-snapshot-row_count]    fail
# 1   None  [metric-snapshot-snapshot-duplicate_count-248c...    pass
# 2     id  [metric-snapshot-snapshot-id-missing_count-248...    pass
# 3   mail  [metric-snapshot-snapshot-mail-invalid_count-6...    pass
# 4    ssn  [metric-snapshot-snapshot-ssn-invalid_percent-...    fail
#
#                                          diagnostics
# 0  {'value': 14, 'fail': {'greaterThan': 13.0, 'l...
# 1  {'value': 0, 'fail': {'greaterThan': 0.0, 'les...
# 2  {'value': 0, 'fail': {'greaterThan': 0.0, 'les...
# 3  {'value': 0, 'fail': {'greaterThan': 0.0, 'les...
# 4  {'value': 100.0, 'fail': {'greaterThan': 0.0, ...

# %%
for ele in scan._metrics:
    print(ele.get_cloud_dict())
pd.DataFrame([ele.get_cloud_dict() for ele in scan._metrics])
# Out:
# {'identity': 'metric-snapshot-snapshot-duplicate_count-248c8fa3', 'metricName': 'duplicate_count', 'value': 0}
# {'identity': 'metric-snapshot-snapshot-ssn-invalid_percent-3a74e0ac', 'metricName': 'invalid_percent', 'value': 100.0}
# {'identity': 'metric-snapshot-snapshot-row_count-0496d604', 'metricName': 'row_count', 'value': 14}
# {'identity': 'metric-snapshot-snapshot-ssn-invalid_count-3a74e0ac', 'metricName': 'invalid_count', 'value': 14}
# {'identity': 'metric-snapshot-snapshot-row_count', 'metricName': 'row_count', 'value': 14}
# {'identity': 'metric-snapshot-snapshot-mail-invalid_count-61813b33', 'metricName': 'invalid_count', 'value': 0}
# {'identity': 'metric-snapshot-snapshot-id-missing_count-248c8fa3', 'metricName': 'missing_count', 'value': 0}
#                                             identity       metricName  value
# 0  metric-snapshot-snapshot-duplicate_count-248c8fa3  duplicate_count    0.0
# 1  metric-snapshot-snapshot-ssn-invalid_percent-3...  invalid_percent  100.0
# 2        metric-snapshot-snapshot-row_count-0496d604        row_count   14.0
# 3  metric-snapshot-snapshot-ssn-invalid_count-3a7...    invalid_count   14.0
# 4                 metric-snapshot-snapshot-row_count        row_count   14.0
# 5  metric-snapshot-snapshot-mail-invalid_count-61...    invalid_count    0.0
# 6  metric-snapshot-snapshot-id-missing_count-248c...    missing_count    0.0

# %%
import pandas as pd
for ele in scan._profile_columns_result_tables:
    print(ele.get_cloud_dict())
display(pd.DataFrame(ele.get_cloud_dict()))
display(pd.DataFrame(scan._profile_columns_result_tables[0].get_cloud_dict()['columnProfiles']))
# Out:
# {'table': 'snapshot', 'dataSource': 'snapshot', 'columnProfiles': [{'columnName': 'id', 'profile': {'mins': [0.0, 1.0, 3.0, 4.0, 6.0], 'maxs': [19.0, 18.0, 17.0, 16.0, 15.0], 'min': 0.0, 'max': 19.0, 'frequent_values': [{'value': '12', 'frequency': 1}, {'value': '1', 'frequency': 1}, {'value': '13', 'frequency': 1}, {'value': '6', 'frequency': 1}, {'value': '16', 'frequency': 1}, {'value': '3', 'frequency': 1}, {'value': '19', 'frequency': 1}, {'value': '15', 'frequency': 1}, {'value': '9', 'frequency': 1}, {'value': '17', 'frequency': 1}], 'avg': 10.5, 'sum': 147.0, 'stddev': 6.583779601881721, 'variance': 43.34615384615384, 'distinct': 14, 'missing_count': 0, 'histogram': {'boundaries': [0.0, 1.46, 2.92, 4.38, 5.85, 7.31, 8.77, 10.23, 11.69, 13.15, 14.62, 16.08, 17.54, 19.0], 'frequencies': [2, 0, 2, 0, 1, 0, 1, 0, 2, 1, 2, 1, 1, 1]}, 'avg_length': None, 'min_length': None, 'max_length': None}}, {'columnName': 'job', 'profile': {'mins': None, 'maxs': None, 'min': None, 'max': None, 'frequent_values': [{'value': 'Contractor', 'frequency': 1}, {'value': 'Rural practice surveyor', 'frequency': 1}, {'value': 'Museum education officer', 'frequency': 1}, {'value': 'Secondary school teacher', 'frequency': 1}, {'value': 'Pathologist', 'frequency': 1}, {'value': 'Race relations officer', 'frequency': 1}, {'value': 'Surveyor, rural practice', 'frequency': 1}, {'value': 'Newspaper journalist', 'frequency': 1}, {'value': 'Surveyor, commercial/residential', 'frequency': 1}, {'value': 'Geologist, engineering', 'frequency': 1}], 'avg': None, 'sum': None, 'stddev': None, 'variance': None, 'distinct': 14, 'missing_count': 0, 'histogram': None, 'avg_length': 20, 'min_length': 10, 'max_length': 32}}, {'columnName': 'company', 'profile': {'mins': None, 'maxs': None, 'min': None, 'max': None, 'frequent_values': [{'value': 'Hernandez Ltd', 'frequency': 1}, {'value': 'Gordon-Smith', 'frequency': 1}, {'value': 'Baldwin Group', 'frequency': 1}, {'value': 'Rodriguez-Williams', 'frequency': 1}, {'value': 'Alexander-Weaver', 'frequency': 1}, {'value': 'Boone, Gallagher and Scott', 'frequency': 1}, {'value': 'Kelly-Singh', 'frequency': 1}, {'value': 'Osborne PLC', 'frequency': 1}, {'value': 'Jackson-Davis', 'frequency': 1}, {'value': 'Larson PLC', 'frequency': 1}], 'avg': None, 'sum': None, 'stddev': None, 'variance': None, 'distinct': 14, 'missing_count': 0, 'histogram': None, 'avg_length': 15, 'min_length': 9, 'max_length': 28}}, {'columnName': 'ssn', 'profile': {'mins': None, 'maxs': None, 'min': None, 'max': None, 'frequent_values': [{'value': '861-51-6071', 'frequency': 1}, {'value': '586-63-4366', 'frequency': 1}, {'value': '798-56-9807', 'frequency': 1}, {'value': '412-92-6966', 'frequency': 1}, {'value': '508-98-7365', 'frequency': 1}, {'value': '418-26-0136', 'frequency': 1}, {'value': '402-72-6549', 'frequency': 1}, {'value': '627-52-4610', 'frequency': 1}, {'value': '498-01-2910', 'frequency': 1}, {'value': '308-98-1651', 'frequency': 1}], 'avg': None, 'sum': None, 'stddev': None, 'variance': None, 'distinct': 14, 'missing_count': 0, 'histogram': None, 'avg_length': 11, 'min_length': 11, 'max_length': 11}}, {'columnName': 'website', 'profile': {'mins': None, 'maxs': None, 'min': None, 'max': None, 'frequent_values': [{'value': "['https://evans.info/', 'http://www.choi.com/']", 'frequency': 1}, {'value': "['https://turner-hunter.org/', 'http://www.fields-vang.org/', 'http://morales-zuniga.com/', 'http://www.reyes.com/']", 'frequency': 1}, {'value': "['http://www.hart.com/', 'http://www.edwards.com/', 'https://howard-molina.com/', 'https://www.lynch.com/']", 'frequency': 1}, {'value': "['https://www.lara.com/', 'https://www.hampton.com/']", 'frequency': 1}, {'value': "['http://www.english.com/', 'https://wilson.com/', 'http://www.sanders.com/', 'http://www.pacheco.com/']", 'frequency': 1}, {'value': "['http://www.jackson.com/']", 'frequency': 1}, {'value': "['https://www.pearson.com/', 'http://carlson.com/', 'http://booker.org/', 'https://white ...
#        table dataSource                                     columnProfiles
# 0   snapshot   snapshot  {'columnName': 'id', 'profile': {'mins': [0.0,...
# 1   snapshot   snapshot  {'columnName': 'job', 'profile': {'mins': None...
# 2   snapshot   snapshot  {'columnName': 'company', 'profile': {'mins': ...
# 3   snapshot   snapshot  {'columnName': 'ssn', 'profile': {'mins': None...
# 4   snapshot   snapshot  {'columnName': 'website', 'profile': {'mins': ...
# 5   snapshot   snapshot  {'columnName': 'username', 'profile': {'mins':...
# 6   snapshot   snapshot  {'columnName': 'name', 'profile': {'mins': Non...
# 7   snapshot   snapshot  {'columnName': 'address', 'profile': {'mins': ...
# 8   snapshot   snapshot  {'columnName': 'mail', 'profile': {'mins': Non...
# 9   snapshot   snapshot  {'columnName': 'birthdate', 'profile': {'mins'...
# 10  snapshot   snapshot  {'columnName': '_delivery', 'profile': {'mins'...
#    columnName                                            profile
# 0          id  {'mins': [0.0, 1.0, 3.0, 4.0, 6.0], 'maxs': [1...
# 1         job  {'mins': None, 'maxs': None, 'min': None, 'max...
# 2     company  {'mins': None, 'maxs': None, 'min': None, 'max...
# 3         ssn  {'mins': None, 'maxs': None, 'min': None, 'max...
# 4     website  {'mins': None, 'maxs': None, 'min': None, 'max...
# 5    username  {'mins': None, 'maxs': None, 'min': None, 'max...
# 6        name  {'mins': None, 'maxs': None, 'min': None, 'max...
# 7     address  {'mins': None, 'maxs': None, 'min': None, 'max...
# 8        mail  {'mins': None, 'maxs': None, 'min': None, 'max...
# 9   birthdate  {'mins': None, 'maxs': None, 'min': None, 'max...
# 10  _delivery  {'mins': None, 'maxs': None, 'min': None, 'max...
