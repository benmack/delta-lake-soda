# %% [markdown]
# # Soda scan delta table

# %% [markdown]
# ## Setup

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from ipywidgets import Output
import pandas as pd
from pathlib import Path 
from soda.scan import Scan
from soda.common.json_helper import JsonHelper

from delta import *
from pyspark.sql import SparkSession
from pyspark.sql.functions import input_file_name, split, regexp_extract, to_timestamp

from utils.data_generation import FakerProfileDataSnapshot
from utils.soda_utils import build_scan_results, save_scan_results_with_spark_as_json

# %%
builder = SparkSession.builder.appName("data-pipeline") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
# object for data generation
datagen = FakerProfileDataSnapshot(
    data_dir=str(Path('./data').resolve())
)
# clean landing storage
datagen.delete_batches_in_landing_dir()
datagen.delete_bronze_dir()
datagen.delete_bronze_scan_results_dir()
# Out:
# Directory does ot exist.
# /home/jovyan/work/data/bronze

# %% [markdown]
# ## Parameters

# %%
read_csv_options = {'header': 'true', 'inferSchema': 'true', 'delimiter': ',', 'quote': '"', 'multiLine': 'true'}

# %%
location_landing = datagen.landing_dir
location_bronze = datagen.bronze_dir
location_bronze_scan_results = datagen.bronze_scan_results_dir

# %%
sodacl_yaml_str = '''
checks for snapshot:
  - freshness(_delivery_date, FAKE_NOW) < 8d
  - schema:
      fail:
        when required column missing:
          - id
          - mail
          - birthdate
      warn:
        when required column missing: [_last_modified_timestamp, _delivery_date]
  - row_count > 0
  - duplicate_count(id) = 0
  - duplicate_count(mail) = 0
  - missing_count(id) = 0
  - invalid_count(mail) = 0:
      valid format: email
  - invalid_percent(birthdate) = 0:
      valid length: 10
discover tables:
  tables:
    - include snapshot
profile columns:
  columns:
    - snapshot.%
'''

# %% [markdown]
# ## Processing
#
# ### Generate data - CSV

# %%
batch_id = 7

path_csv = datagen.land_batch(batch_id)
path_csv
# Out:
# '/home/jovyan/work/data/landing/snapshot_2022-09-30.csv'

# %% [markdown]
# ### Create delta table

# %%
df = spark.read.format('csv').options(**read_csv_options).load(str(path_csv)) \
    .withColumn("_delivery_date", 
                to_timestamp(
                    regexp_extract(
                        input_file_name(), '.*_(.*).csv$', 1
                    )
                )
               )
df.toPandas()
# Out:
#     id                               job                       company  \
# 0    0                        Contractor    Boone, Gallagher and Scott
# 1    1           Rural practice surveyor                   Osborne PLC
# 2    3              Newspaper journalist                  Gordon-Smith
# 3    4               Programmer, systems            Rodriguez-Williams
# 4    6          Surveyor, rural practice                 Jackson-Davis
# 5    9  Surveyor, commercial/residential                   Kelly-Singh
# 6   12          Secondary school teacher                 Hernandez Ltd
# 7   13            Race relations officer     Jones, Randall and Cherry
# 8   14          Radiographer, diagnostic                 Baldwin Group
# 9   15            Geologist, engineering               Fernandez Group
# 10  16                Investment analyst                     Adams Inc
# 11  17          Museum education officer  Hoffman, Andrade and Stevens
# 12  18              Engineer, biomedical              Alexander-Weaver
# 13  19                       Pathologist                    Larson PLC
#
#             ssn                                            website  \
# 0   508-98-7365  ['https://hall.info/', 'https://www.monroe-haw...
# 1   861-51-6071  ['https://kelley.net/', 'http://www.herring-ca...
# 2   627-52-4610                        ['http://www.jackson.com/']
# 3   303-02-0239  ['https://www.pearson.com/', 'http://carlson.c...
# 4   498-01-2910    ['https://evans.info/', 'http://www.choi.com/']
# 5   402-72-6549  ['http://www.english.com/', 'https://wilson.co...
# 6   334-42-9390                             ['http://walker.biz/']
# 7   418-26-0136  ['https://turner-hunter.org/', 'http://www.fie...
# 8   412-92-6966  ['https://shah.net/', 'https://www.cohen-white...
# 9   308-98-1651  ['https://morgan.com/', 'https://www.gordon.co...
# 10  371-04-1284  ['https://www.turner.com/', 'http://www.merrit...
# 11  798-56-9807  ['http://www.hart.com/', 'http://www.edwards.c...
# 12  586-63-4366  ['https://www.lara.com/', 'https://www.hampton...
# 13  725-41-8761  ['https://cunningham-smith.com/', 'https://www...
#
#           username                name  \
# 0          paula86      Misty Phillips
# 1      andreawhite         Alfred Hall
# 2        matthew14        Kyle Randall
# 3           kdavis         Sally Davis
# 4   simpsonphillip          Keith Todd
# 5        rpeterson       Kelsey Ramsey
# 6       harriscarl  Veronica Maldonado
# 7          hbryant         Samuel Mack
# 8        gphillips         Anita Price
# 9         robert00   Courtney Gonzalez
# 10  mcintyredonald       Jill Anderson
# 11    hesterandrew          Lori Kline
# 12      lauraboyle     Alison Robinson
# 13  johnsonrichard    Taylor Hernandez
#
#                                               address  \
# 0          4978 Chapman Bypass\nSanchezfurt, TN 23177
# 1   11070 Wright Creek Apt. 541\nEast Jonathan, TN...
# 2       98150 Jones Way Apt. 251\nJonesside, OK 11215
# 3            4052 Sparks Prairie\nJohnville, RI 76389
# 4   280 Lindsey Road Apt. 412\nSouth Melissabury, ...
# 5       36377 Christensen Fort\nPort Justin, OR 51565
# 6          32860 Yoder Oval\nJeffreyborough, NM 31331
# 7        2024 Hodge Radial\nStefaniechester, NY 38154
# 8   97126 Gary Glens Suite 847\nPort Katherine, NM...
# 9            34549 Johnson Isle\nDonaldview, WI 19280
# 10         5542 Melinda Light\nSullivanberg, LA 87910
# 11                   PSC 6263, Box 1355\nAPO AP 32636
# 12         67190 Davis Court\nWilliamshaven, WI 02095
# 13            928 Sara Vista\nTaylorborough, VA 52559
#
#                          mail   birthdate _delivery_date
# 0             ana51@yahoo.com  1996-12-21     2022-09-30
# 1           shawn57@yahoo.com  1922-03-06     2022-09-30
# 2       michael49@hotmail.com  1922-03-12     2022-09-30
# 3     sanchezandrew@gmail.com  1961-04-26     2022-09-30
# 4           umartin@yahoo.com  1923-10-30     2022-09-30
# 5      shannonscott@yahoo.com  1987-06-05     2022-09-30
# 6         xchavez@hotmail.com  1932-05-02     2022-09-30
# 7          bvazquez@yahoo.com  2012-05-20     2022-09-30
# 8       toddjessica@yahoo.com  2003-02-07     2022-09-30
# 9   reedchristopher@gmail.com  1947-06-19     2022-09-30
# 10     medinaalec@hotmail.com  1924-09-05     2022-09-30
# 11            xpaul@yahoo.com  1995-04-18     2022-09-30
# 12       moseslarry@yahoo.com  2005-01-10     2022-09-30
# 13        kaitlyn23@yahoo.com  2003-03-06     2022-09-30

# %%
df.write.format('delta').option('overwriteSchema', 'true').mode('overwrite').save(location_bronze)

# %%
spark.sql('DROP TABLE IF EXISTS snapshot')
spark.sql(f'CREATE TABLE IF NOT EXISTS snapshot USING DELTA LOCATION "{location_bronze}"')
# Out:
# DataFrame[]

# %%
spark.sql(f'DESCRIBE HISTORY snapshot').toPandas()
# Out:
#    version               timestamp userId userName operation  \
# 0        0 2022-08-21 16:36:46.840   None     None     WRITE
#
#                           operationParameters   job notebook clusterId  \
# 0  {'mode': 'Overwrite', 'partitionBy': '[]'}  None     None      None
#
#    readVersion isolationLevel  isBlindAppend  \
# 0          NaN   Serializable          False
#
#                                     operationMetrics userMetadata  \
# 0  {'numOutputRows': '14', 'numOutputBytes': '626...         None
#
#                             engineInfo
# 0  Apache-Spark/3.2.1 Delta-Lake/2.0.0

# %% [markdown]
# ### Run soda scan
#
# ... with checks, discovery, profiling.

# %%
import datetime

scan = Scan()
scan.disable_telemetry()
scan.set_data_source_name('snapshot')
scan.add_spark_session(spark, 'snapshot')

fake_now = datetime.date.fromisoformat('2022-10-01') # should make freshness check fail
scan.add_variables({"FAKE_NOW": f"{fake_now} 00:00:00"})

scan.add_sodacl_yaml_str(sodacl_yaml_str=sodacl_yaml_str)

# we avoid it with the following two lines instead
output = Output()
with output:
    exit_code = scan.execute()
exit_code
# Out:
# 1

# %% [markdown]
# ## Soda scan results
#
# ### Create soda cloud scan result data structure
#
# Source of the code below
# * discussion in PR 1406 https://github.com/sodadata/soda-core/pull/1406)
# * implementation and the implementation https://github.com/sodadata/soda-core/blob/b4f3d692fd912cc4fc4964c293debd09deb09551/soda/core/soda/scan.py
#
# Be aware of the caveat (cited from PR discussion):
#
# *Exposing this data is a good idea. But it should be done in a dedicated data structure. I see you have recycled the soda cloud data structure, which is not suitable for this use case.*
#
# [...]
#
# *It's not intended for external usage. We cannot give any stability guarantees on it.*
#
# [...]
#
# *The better long term solution is introducing stable scan results data classes. That's something that we ll put on our roadmap.*

# %%
scan_results = build_scan_results(scan)
scan_results.keys()
# Out:
# dict_keys(['definitionName', 'defaultDataSource', 'dataTimestamp', 'scanStartTimestamp', 'scanEndTimestamp', 'hasErrors', 'hasWarnings', 'hasFailures', 'metrics', 'checks', 'automatedMonitoringChecks', 'profiling', 'metadata', 'logs'])

# %% [markdown]
# ### Investigate scan results
#
# #### Investigate non-list entries

# %%
for key, value in scan_results.items():
    if type(value) != list:
        print('*' * 40)
        print(key)
        print('-' * 20)
        print(value)
# Out:
# ****************************************
# definitionName
# --------------------
# None
# ****************************************
# defaultDataSource
# --------------------
# snapshot
# ****************************************
# dataTimestamp
# --------------------
# 2022-08-21T16:36:57+00:00
# ****************************************
# scanStartTimestamp
# --------------------
# 2022-08-21T16:36:57+00:00
# ****************************************
# scanEndTimestamp
# --------------------
# 2022-08-21T16:37:40+00:00
# ****************************************
# hasErrors
# --------------------
# False
# ****************************************
# hasWarnings
# --------------------
# True
# ****************************************
# hasFailures
# --------------------
# False

# %% [markdown]
# #### Investigate list entries

# %%
[key for key, value in scan_results.items() if type(value) == list]
# Out:
# ['metrics',
#  'checks',
#  'automatedMonitoringChecks',
#  'profiling',
#  'metadata',
#  'logs']

# %% [markdown]
# #### metrics

# %%
pd.DataFrame(scan_results['metrics'])
# Out:
#                                             identity       metricName  \
# 0                 metric-snapshot-snapshot-row_count        row_count
# 1                    metric-snapshot-snapshot-schema           schema
# 2        metric-snapshot-snapshot-id-duplicate_count  duplicate_count
# 3  metric-snapshot-snapshot-birthdate-invalid_cou...    invalid_count
# 4      metric-snapshot-snapshot-mail-duplicate_count  duplicate_count
# 5  metric-snapshot-snapshot-mail-invalid_count-61...    invalid_count
# 6  metric-snapshot-snapshot-birthdate-invalid_per...  invalid_percent
# 7        metric-snapshot-snapshot-_delivery_date-max              max
# 8          metric-snapshot-snapshot-id-missing_count    missing_count
#
#                                                value dataSourceName tableName  \
# 0                                                 14            NaN       NaN
# 1  [{'columnName': 'id', 'sourceDataType': 'int'}...       snapshot  snapshot
# 2                                                  0            NaN       NaN
# 3                                                  0            NaN       NaN
# 4                                                  0            NaN       NaN
# 5                                                  0            NaN       NaN
# 6                                                0.0            NaN       NaN
# 7                          2022-09-30T00:00:00+00:00            NaN       NaN
# 8                                                  0            NaN       NaN
#
#    partitionName  columnName
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN

# %% [markdown]
# #### checks

# %%
pd.DataFrame(scan_results['checks'])
# Out:
#    identity                                      name             type  \
# 0  2ed46382                              Schema Check           schema
# 1  0c97eed4                             row_count > 0  metricThreshold
# 2  7dbf4d67  freshness(_delivery_date, FAKE_NOW) < 8d  metricThreshold
# 3  6a2f657f                   duplicate_count(id) = 0  metricThreshold
# 4  33f7df58                     missing_count(id) = 0  metricThreshold
# 5  bd933496                 duplicate_count(mail) = 0  metricThreshold
# 6  55ab369a                   invalid_count(mail) = 0  metricThreshold
# 7  450977ba            invalid_percent(birthdate) = 0  metricThreshold
#
#                                           definition  \
# 0  checks for snapshot:\n  - schema:\n      fail:...
# 1              checks for snapshot:\n  row_count > 0
# 2  checks for snapshot:\n  freshness(_delivery_da...
# 3    checks for snapshot:\n  duplicate_count(id) = 0
# 4      checks for snapshot:\n  missing_count(id) = 0
# 5  checks for snapshot:\n  duplicate_count(mail) = 0
# 6  checks for snapshot:\n  - invalid_count(mail) ...
# 7  checks for snapshot:\n  - invalid_percent(birt...
#
#                                             location dataSource     table  \
# 0  {'filePath': 'sodacl_string.yml', 'line': 4, '...   snapshot  snapshot
# 1  {'filePath': 'sodacl_string.yml', 'line': 12, ...   snapshot  snapshot
# 2  {'filePath': 'sodacl_string.yml', 'line': 3, '...   snapshot  snapshot
# 3  {'filePath': 'sodacl_string.yml', 'line': 13, ...   snapshot  snapshot
# 4  {'filePath': 'sodacl_string.yml', 'line': 15, ...   snapshot  snapshot
# 5  {'filePath': 'sodacl_string.yml', 'line': 14, ...   snapshot  snapshot
# 6  {'filePath': 'sodacl_string.yml', 'line': 16, ...   snapshot  snapshot
# 7  {'filePath': 'sodacl_string.yml', 'line': 18, ...   snapshot  snapshot
#
#            column                                            metrics outcome  \
# 0            None                  [metric-snapshot-snapshot-schema]    warn
# 1            None               [metric-snapshot-snapshot-row_count]    pass
# 2  _delivery_date      [metric-snapshot-snapshot-_delivery_date-max]    pass
# 3              id      [metric-snapshot-snapshot-id-duplicate_count]    pass
# 4              id        [metric-snapshot-snapshot-id-missing_count]    pass
# 5            mail    [metric-snapshot-snapshot-mail-duplicate_count]    pass
# 6            mail  [metric-snapshot-snapshot-mail-invalid_count-6...    pass
# 7       birthdate  [metric-snapshot-snapshot-birthdate-invalid_pe...    pass
#
#                                          diagnostics
# 0  {'schema': [{'columnName': 'id', 'sourceDataTy...
# 1    {'value': 14, 'fail': {'lessThanOrEqual': 0.0}}
# 2  {'value': 0, 'maxColumnTimestamp': '2022-09-30...
# 3  {'value': 0, 'fail': {'greaterThan': 0.0, 'les...
# 4  {'value': 0, 'fail': {'greaterThan': 0.0, 'les...
# 5  {'value': 0, 'fail': {'greaterThan': 0.0, 'les...
# 6  {'value': 0, 'fail': {'greaterThan': 0.0, 'les...
# 7  {'value': 0.0, 'fail': {'greaterThan': 0.0, 'l...

# %%
scan_results['checks'][0]['location']
# Out:
# {'filePath': 'sodacl_string.yml', 'line': 4, 'col': 5}

# %%
pd.json_normalize(pd.DataFrame(scan_results['checks'])['location'])
# Out:
#             filePath  line  col
# 0  sodacl_string.yml     4    5
# 1  sodacl_string.yml    12    5
# 2  sodacl_string.yml     3    5
# 3  sodacl_string.yml    13    5
# 4  sodacl_string.yml    15    5
# 5  sodacl_string.yml    14    5
# 6  sodacl_string.yml    16    5
# 7  sodacl_string.yml    18    5

# %%
scan_results['checks'][0]['diagnostics']
# Out:
# {'schema': [{'columnName': 'id', 'sourceDataType': 'int'},
#   {'columnName': 'job', 'sourceDataType': 'string'},
#   {'columnName': 'company', 'sourceDataType': 'string'},
#   {'columnName': 'ssn', 'sourceDataType': 'string'},
#   {'columnName': 'website', 'sourceDataType': 'string'},
#   {'columnName': 'username', 'sourceDataType': 'string'},
#   {'columnName': 'name', 'sourceDataType': 'string'},
#   {'columnName': 'address', 'sourceDataType': 'string'},
#   {'columnName': 'mail', 'sourceDataType': 'string'},
#   {'columnName': 'birthdate', 'sourceDataType': 'string'},
#   {'columnName': '_delivery_date', 'sourceDataType': 'timestamp'},
#   {'columnName': '', 'sourceDataType': ''},
#   {'columnName': '# Partitioning', 'sourceDataType': ''},
#   {'columnName': 'Not partitioned', 'sourceDataType': ''}]}

# %%
pd.json_normalize(pd.DataFrame(scan_results['checks'])['diagnostics'])
# Out:
#                                               schema  value  \
# 0  [{'columnName': 'id', 'sourceDataType': 'int'}...    NaN
# 1                                                NaN   14.0
# 2                                                NaN    0.0
# 3                                                NaN    0.0
# 4                                                NaN    0.0
# 5                                                NaN    0.0
# 6                                                NaN    0.0
# 7                                                NaN    0.0
#
#    fail.lessThanOrEqual   maxColumnTimestamp      maxColumnTimestampUtc  \
# 0                   NaN                  NaN                        NaN
# 1                   0.0                  NaN                        NaN
# 2                   NaN  2022-09-30 00:00:00  2022-09-30 00:00:00+00:00
# 3                   NaN                  NaN                        NaN
# 4                   NaN                  NaN                        NaN
# 5                   NaN                  NaN                        NaN
# 6                   NaN                  NaN                        NaN
# 7                   NaN                  NaN                        NaN
#
#   nowVariableName         nowTimestamp            nowTimestampUtc  \
# 0             NaN                  NaN                        NaN
# 1             NaN                  NaN                        NaN
# 2        FAKE_NOW  2022-10-01 00:00:00  2022-10-01 00:00:00+00:00
# 3             NaN                  NaN                        NaN
# 4             NaN                  NaN                        NaN
# 5             NaN                  NaN                        NaN
# 6             NaN                  NaN                        NaN
# 7             NaN                  NaN                        NaN
#
#         freshness  fail.greaterThan  fail.lessThan
# 0             NaN               NaN            NaN
# 1             NaN               NaN            NaN
# 2  1 day, 0:00:00               NaN            NaN
# 3             NaN               0.0            0.0
# 4             NaN               0.0            0.0
# 5             NaN               0.0            0.0
# 6             NaN               0.0            0.0
# 7             NaN               0.0            0.0

# %% [markdown]
# #### automatedMonitoringChecks

# %%
pd.DataFrame(scan_results['automatedMonitoringChecks'])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### profiling

# %%
pd.DataFrame(scan_results['profiling'])
# Out:
#       table dataSource                                     columnProfiles
# 0  snapshot   snapshot  [{'columnName': 'id', 'profile': {'mins': [0.0...

# %%
pd.DataFrame(scan_results['profiling'][0]['columnProfiles'])
# Out:
#   columnName                                            profile
# 0         id  {'mins': [0.0, 1.0, 3.0, 4.0, 6.0], 'maxs': [1...
# 1        job  {'mins': None, 'maxs': None, 'min': None, 'max...
# 2    company  {'mins': None, 'maxs': None, 'min': None, 'max...
# 3        ssn  {'mins': None, 'maxs': None, 'min': None, 'max...
# 4    website  {'mins': None, 'maxs': None, 'min': None, 'max...
# 5   username  {'mins': None, 'maxs': None, 'min': None, 'max...
# 6       name  {'mins': None, 'maxs': None, 'min': None, 'max...
# 7    address  {'mins': None, 'maxs': None, 'min': None, 'max...
# 8       mail  {'mins': None, 'maxs': None, 'min': None, 'max...
# 9  birthdate  {'mins': None, 'maxs': None, 'min': None, 'max...

# %%
def long_dataframe_from_profiling_results(profiling_list: list):
    df_tables = pd.DataFrame(profiling_list)
    df_all_metrics = []
    for table_id, row in df_tables.iterrows():
        df_col = pd.DataFrame(row['columnProfiles'])
        df_col['table_id'] = table_id
        df_met = pd.json_normalize(df_col['profile']).melt(var_name='metricName', ignore_index=False)
        df_all_metrics.append(
            pd.merge(df_col.drop('profile', axis=1), 
                     df_met, 
                     left_index=True, right_index=True)
        )
    df_all_metrics= pd.concat(df_all_metrics)
    return pd.merge(
        df_tables.drop('columnProfiles', axis=1), 
        df_all_metrics, 
        left_index=True, right_on='table_id').drop('table_id', axis=1)
    
df_profiling = long_dataframe_from_profiling_results(scan_results['profiling'])
print(df_profiling['metricName'].unique())
df_profiling
# Out:
# ['mins' 'maxs' 'min' 'max' 'frequent_values' 'avg' 'sum' 'stddev'
#  'variance' 'distinct' 'missing_count' 'avg_length' 'min_length'
#  'max_length' 'histogram.boundaries' 'histogram.frequencies' 'histogram']
#        table dataSource columnName             metricName  \
# 0   snapshot   snapshot         id                   mins
# 0   snapshot   snapshot         id                   maxs
# 0   snapshot   snapshot         id                    min
# 0   snapshot   snapshot         id                    max
# 0   snapshot   snapshot         id        frequent_values
# ..       ...        ...        ...                    ...
# 9   snapshot   snapshot  birthdate             min_length
# 9   snapshot   snapshot  birthdate             max_length
# 9   snapshot   snapshot  birthdate   histogram.boundaries
# 9   snapshot   snapshot  birthdate  histogram.frequencies
# 9   snapshot   snapshot  birthdate              histogram
#
#                                                 value
# 0                           [0.0, 1.0, 3.0, 4.0, 6.0]
# 0                      [19.0, 18.0, 17.0, 16.0, 15.0]
# 0                                                 0.0
# 0                                                19.0
# 0   [{'value': '12', 'frequency': 1}, {'value': '1...
# ..                                                ...
# 9                                                10.0
# 9                                                10.0
# 9                                                 NaN
# 9                                                 NaN
# 9                                                 NaN
#
# [170 rows x 5 columns]

# %%
df_profiling.query('metricName == "missing_count"')
# Out:
#       table dataSource columnName     metricName value
# 0  snapshot   snapshot         id  missing_count     0
# 1  snapshot   snapshot        job  missing_count     0
# 2  snapshot   snapshot    company  missing_count     0
# 3  snapshot   snapshot        ssn  missing_count     0
# 4  snapshot   snapshot    website  missing_count     0
# 5  snapshot   snapshot   username  missing_count     0
# 6  snapshot   snapshot       name  missing_count     0
# 7  snapshot   snapshot    address  missing_count     0
# 8  snapshot   snapshot       mail  missing_count     0
# 9  snapshot   snapshot  birthdate  missing_count     0

# %% [markdown]
# #### metadata

# %%
pd.DataFrame(scan_results['metadata'])
# Out:
#       table dataSource  rowCount  \
# 0  snapshot   snapshot        14
#
#                                               schema
# 0  [{'columnName': 'id', 'sourceDataType': 'int'}...

# %%
scan_results['metadata'][0]['schema']
# Out:
# [{'columnName': 'id', 'sourceDataType': 'int'},
#  {'columnName': 'job', 'sourceDataType': 'string'},
#  {'columnName': 'company', 'sourceDataType': 'string'},
#  {'columnName': 'ssn', 'sourceDataType': 'string'},
#  {'columnName': 'website', 'sourceDataType': 'string'},
#  {'columnName': 'username', 'sourceDataType': 'string'},
#  {'columnName': 'name', 'sourceDataType': 'string'},
#  {'columnName': 'address', 'sourceDataType': 'string'},
#  {'columnName': 'mail', 'sourceDataType': 'string'},
#  {'columnName': 'birthdate', 'sourceDataType': 'string'},
#  {'columnName': '_delivery_date', 'sourceDataType': 'timestamp'},
#  {'columnName': '', 'sourceDataType': ''},
#  {'columnName': '# Partitioning', 'sourceDataType': ''},
#  {'columnName': 'Not partitioned', 'sourceDataType': ''}]

# %%
pd.DataFrame(scan_results['metadata'][0]['schema'])
# Out:
#          columnName sourceDataType
# 0                id            int
# 1               job         string
# 2           company         string
# 3               ssn         string
# 4           website         string
# 5          username         string
# 6              name         string
# 7           address         string
# 8              mail         string
# 9         birthdate         string
# 10   _delivery_date      timestamp
# 11
# 12   # Partitioning
# 13  Not partitioned

# %% [markdown]
# #### logs

# %%
pd.DataFrame(scan_results['logs'])
# Out:
#    level                                            message  \
# 0   info                                    Soda Core 3.0.4
# 1   info  Running discover datasets for data source: sna...
# 2   info                  Discovering the following tables:
# 3   info                                         - snapshot
# 4   info  Running column profiling for data source: snap...
# 5   info        Profiling columns for the following tables:
# 6   info                                         - snapshot
# 7   info                                      Scan summary:
# 8   info                                7/8 checks PASSED:
# 9   info                               snapshot in snapshot
# 10  info                             row_count > 0 [PASSED]
# 11  info        freshness(_delivery_date, FAKE_NOW) < 8d...
# 12  info                   duplicate_count(id) = 0 [PASSED]
# 13  info                     missing_count(id) = 0 [PASSED]
# 14  info                 duplicate_count(mail) = 0 [PASSED]
# 15  info                   invalid_count(mail) = 0 [PASSED]
# 16  info            invalid_percent(birthdate) = 0 [PASSED]
# 17  info                                1/8 checks WARNED:
# 18  info                               snapshot in snapshot
# 19  info                              Schema Check [WARNED]
# 20  info          missing_column_names = [_last_modified...
# 21  info          schema_measured = [id int, job string,...
# 22  info       Only 1 warning. 0 failure. 0 errors. 7 pass.
#
#                     timestamp  index
# 0   2022-08-21T16:36:57+00:00      1
# 1   2022-08-21T16:37:07+00:00      2
# 2   2022-08-21T16:37:07+00:00      3
# 3   2022-08-21T16:37:07+00:00      4
# 4   2022-08-21T16:37:08+00:00      5
# 5   2022-08-21T16:37:08+00:00      6
# 6   2022-08-21T16:37:08+00:00      7
# 7   2022-08-21T16:37:40+00:00      8
# 8   2022-08-21T16:37:40+00:00      9
# 9   2022-08-21T16:37:40+00:00     10
# 10  2022-08-21T16:37:40+00:00     11
# 11  2022-08-21T16:37:40+00:00     12
# 12  2022-08-21T16:37:40+00:00     13
# 13  2022-08-21T16:37:40+00:00     14
# 14  2022-08-21T16:37:40+00:00     15
# 15  2022-08-21T16:37:40+00:00     16
# 16  2022-08-21T16:37:40+00:00     17
# 17  2022-08-21T16:37:40+00:00     18
# 18  2022-08-21T16:37:40+00:00     19
# 19  2022-08-21T16:37:40+00:00     20
# 20  2022-08-21T16:37:40+00:00     21
# 21  2022-08-21T16:37:40+00:00     22
# 22  2022-08-21T16:37:40+00:00     23

# %% [markdown]
# ### Save and read with Spark

# %% [markdown]
# #### Save to json with Spark

# %%
# also implemented in utils.soda_utils.save_scan_results_with_spark_as_json
rdd = spark.sparkContext.parallelize([JsonHelper.to_json(scan_results)])
rdd.coalesce(1).saveAsTextFile(location_bronze_scan_results + f'/scan_result_{batch_id}.json')

# %% [markdown]
# #### Read json with Spark

# %%
sdf_sr = spark.read.json(location_bronze_scan_results + f'/scan_result_{batch_id}.json')
sdf_sr.printSchema()
# Out:
# root
#  |-- automatedMonitoringChecks: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- checks: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- column: string (nullable = true)
#  |    |    |-- dataSource: string (nullable = true)
#  |    |    |-- definition: string (nullable = true)
#  |    |    |-- diagnostics: struct (nullable = true)
#  |    |    |    |-- fail: struct (nullable = true)
#  |    |    |    |    |-- greaterThan: double (nullable = true)
#  |    |    |    |    |-- lessThan: double (nullable = true)
#  |    |    |    |    |-- lessThanOrEqual: double (nullable = true)
#  |    |    |    |-- freshness: string (nullable = true)
#  |    |    |    |-- maxColumnTimestamp: string (nullable = true)
#  |    |    |    |-- maxColumnTimestampUtc: string (nullable = true)
#  |    |    |    |-- nowTimestamp: string (nullable = true)
#  |    |    |    |-- nowTimestampUtc: string (nullable = true)
#  |    |    |    |-- nowVariableName: string (nullable = true)
#  |    |    |    |-- schema: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- columnName: string (nullable = true)
#  |    |    |    |    |    |-- sourceDataType: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |    |-- identity: string (nullable = true)
#  |    |    |-- location: struct (nullable = true)
#  |    |    |    |-- col: long (nullable = true)
#  |    |    |    |-- filePath: string (nullable = true)
#  |    |    |    |-- line: long (nullable = true)
#  |    |    |-- metrics: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- outcome: string (nullable = true)
#  |    |    |-- table: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- dataTimestamp: string (nullable = true)
#  |-- defaultDataSource: string (nullable = true)
#  |-- definitionName: string (nullable = true)
#  |-- hasErrors: boolean (nullable = true)
#  |-- hasFailures: boolean (nullable = true)
#  |-- hasWarnings: boolean (nullable = true)
#  |-- logs: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- index: long (nullable = true)
#  |    |    |-- level: string (nullable = true)
#  |    |    |-- message: string (nullable = true)
#  |    |    |-- timestamp: string (nullable = true)
#  |-- metadata: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- dataSource: string (nullable = true)
#  |    |    |-- rowCount: long (nullable = true)
#  |    |    |-- schema: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- columnName: string (nullable = true)
#  |    |    |    |    |-- sourceDataType: string (nullable = true)
#  |    |    |-- table: string (nullable = true)
#  |-- metrics: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- columnName: string (nullable = true)
#  |    |    |-- dataSourceName: string (nullable = true)
#  |    |    |-- identity: string (nullable = true)
#  |    |    |-- metricName: string (nullable = true)
#  |    |    |-- partitionName: string (nullable = true)
#  |    |    |-- tableName: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |-- profiling: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- columnProfiles: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- columnName: string (nullable = true)
#  |    |    |    |    |-- profile: struct (nullable = true)
#  |    |    |    |    |    |-- avg: double (nullable = true)
#  |    |    |    |    |    |-- avg_length: long (nullable = true)
#  |    |    |    |    |    |-- distinct: long (nullable = true)
#  |    |    |    |    |    |-- frequent_values: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- frequency: long (nullable = true)
#  |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |-- histogram: struct (nullable = true)
#  |    |    |    |    |    |    |-- boundaries: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |    |    |-- frequencies: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- max: double (nullable = true)
#  |    |    |    |    |    |-- max_length: long (nullable = true)
#  |    |    |    |    |    |-- maxs: array (nullable = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |    |-- min: double (nullable = true)
#  |    |    |    |    |    |-- min_length: long (nullable = true)
#  |    |    |    |    |    |-- mins: array (nullable = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |    |-- missing_count: long (nullable = true)
#  |    |    |    |    |    |-- stddev: double (nullable = true)
#  |    |    |    |    |    |-- sum: double (nullable = true)
#  |    |    |    |    |    |-- variance: double (nullable = true)
#  |    |    |-- dataSource: string (nullable = true)
#  |    |    |-- table: string (nullable = true)
#  |-- scanEndTimestamp: string (nullable = true)
#  |-- scanStartTimestamp: string (nullable = true)

# %% [markdown]
# ### Print complete scan result dictionary

# %%
print(JsonHelper.to_json_pretty(scan_results))
# Out:
# {
#   "definitionName": null,
#   "defaultDataSource": "snapshot",
#   "dataTimestamp": "2022-08-21T16:36:57+00:00",
#   "scanStartTimestamp": "2022-08-21T16:36:57+00:00",
#   "scanEndTimestamp": "2022-08-21T16:37:40+00:00",
#   "hasErrors": false,
#   "hasWarnings": true,
#   "hasFailures": false,
#   "metrics": [
#     {
#       "identity": "metric-snapshot-snapshot-row_count",
#       "metricName": "row_count",
#       "value": 14
#     },
#     {
#       "identity": "metric-snapshot-snapshot-schema",
#       "metricName": "schema",
#       "dataSourceName": "snapshot",
#       "tableName": "snapshot",
#       "partitionName": null,
#       "columnName": null,
#       "value": [
#         {
#           "columnName": "id",
#           "sourceDataType": "int"
#         },
#         {
#           "columnName": "job",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "company",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "ssn",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "website",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "username",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "name",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "address",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "mail",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "birthdate",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "_delivery_date",
#           "sourceDataType": "timestamp"
#         },
#         {
#           "columnName": "",
#           "sourceDataType": ""
#         },
#         {
#           "columnName": "# Partitioning",
#           "sourceDataType": ""
#         },
#         {
#           "columnName": "Not partitioned",
#           "sourceDataType": ""
#         }
#       ]
#     },
#     {
#       "identity": "metric-snapshot-snapshot-id-duplicate_count",
#       "metricName": "duplicate_count",
#       "value": 0
#     },
#     {
#       "identity": "metric-snapshot-snapshot-birthdate-invalid_count-80094729",
#       "metricName": "invalid_count",
#       "value": 0
#     },
#     {
#       "identity": "metric-snapshot-snapshot-mail-duplicate_count",
#       "metricName": "duplicate_count",
#       "value": 0
#     },
#     {
#       "identity": "metric-snapshot-snapshot-mail-invalid_count-61813b33",
#       "metricName": "invalid_count",
#       "value": 0
#     },
#     {
#       "identity": "metric-snapshot-snapshot-birthdate-invalid_percent-80094729",
#       "metricName": "invalid_percent",
#       "value": 0.0
#     },
#     {
#       "identity": "metric-snapshot-snapshot-_delivery_date-max",
#       "metricName": "max",
#       "value": "2022-09-30T00:00:00+00:00"
#     },
#     {
#       "identity": "metric-snapshot-snapshot-id-missing_count",
#       "metricName": "missing_count",
#       "value": 0
#     }
#   ],
#   "checks": [
#     {
#       "identity": "2ed46382",
#       "name": "Schema Check",
#       "type": "schema",
#       "definition": "checks for snapshot:\n  - schema:\n      fail:\n        when required column missing:\n          - id\n          - mail\n          - birthdate\n      warn:\n        when required column missing: [_last_modified_timestamp, _delivery_date]\n",
#       "location": {
#         "filePath": "sodacl_string.yml",
#         "line": 4,
#         "col": 5
#       },
#       "dataSource": "snapshot",
#       "table": "snapshot",
#       "column": null,
#       "metrics": [
#         "metric-snapshot-snapshot-schema"
#       ],
#       "outcome": "warn",
#       "diagnostics": {
#         "schema": [
#           {
#             "columnName": "id",
#             "sourceDataType": "int"
#           },
#           {
#             "columnName": "job",
#             "sourceDataType": "string"
#           },
#           {
#             "columnName": "company",
#             "sourceDataType": "string"
#           },
#           {
#             "columnName": "ssn",
#             "sourceDataType": "string"
#           },
#           {
#             "columnName": "website",
#             "sourceDataType": "string"
#           },
#           {
#             "columnName": "username",
#             "sourceDataType": "string"
#           },
#           {
#             "columnName": "name",
#             "sourceDataType": "string"
#           },
#           {
#             "columnName": "address",
#             "sourceDataType": "string"
#           },
#           {
#             "columnName": "mail",
#             "sourceDataType": "string"
#           },
#           {
#             "columnName": "birthdate",
#             "sourceDataType": "string"
#           },
#           {
#             "columnName": "_delivery_date",
#             "sourceDataType": "timestamp"
#           },
#           {
#             "columnName": "",
#             "sourceDataType": ""
#           },
#           {
#             "columnName": "# Partitioning",
#             "sourceDataType": ""
#           },
#           {
#             "columnName": "Not partitioned",
#             "sourceDataType": ""
#           }
#         ]
#       }
#     },
#     {
#       "identity": "0c97eed4",
#       "name": "row_count > 0",
#       "type": "metricThreshold",
#       "definition": "checks for snapshot:\n  row_count > 0",
#       "location": {
#         "filePath": "sodacl_string.yml",
#         "line": 12,
#         "col": 5
#       },
#       "dataSource": "snapshot",
#       "table": "snapshot",
#       "column": null,
#       "metrics": [
#         "metric-snapshot-snapshot-row_count"
#       ],
#       "outcome": "pass",
#       "diagnostics": {
#         "value": 14,
#         "fail": {
#           "lessThanOrEqual": 0.0
#         }
#       }
#     },
#     {
#       "identity": "7dbf4d67",
#       "name": "freshness(_delivery_date, FAKE_NOW) < 8d",
#       "type": "metricThreshold",
#       "definition": "checks for snapshot:\n  freshness(_delivery_date, FAKE_NOW) < 8d",
#       "location": {
#         "filePath": "sodacl_string.yml",
#         "line": 3,
#         "col": 5
#       },
#       "dataSource": "snapshot",
#       "table": "snapshot",
#       "column": "_delivery_date",
#       "metrics": [
#         "metric-snapshot-snapshot-_delivery_date-max"
#       ],
#       "outcome": "pass",
#       "diagnostics": {
#         "value": 0,
#         "maxColumnTimestamp": "2022-09-30 00:00:00",
#         "maxColumnTimestampUtc": "2022-09-30 00:00:00+00:00",
#         "nowVariableName": "FAKE_NOW",
#         "nowTimestamp": "2022-10-01 00:00:00",
#         "nowTimestampUtc": "2022-10-01 00:00:00+00:00",
#         "freshness": "1 day, 0:00:00"
#       }
#     },
#     {
#       "identity": "6a2f657f",
#       "name": "duplicate_count(id) = 0",
#       "type": "metricThreshold",
#       "definition": "checks for snapshot:\n  duplicate_count(id) = 0",
#       "location": {
#         "filePath": "sodacl_string.yml",
#         "line": 13,
#         "col": 5
#       },
#       "dataSource": "snapshot",
#       "table": "snapshot",
#       "column": "id",
#       "metrics": [
#         "metric-snapshot-snapshot-id-duplicate_count"
#       ],
#       "outcome": "pass",
#       "diagnostics": {
#         "value": 0,
#         "fail": {
#           "greaterThan": 0.0,
#           "lessThan": 0.0
#         }
#       }
#     },
#     {
#       "identity": "33f7df58",
#       "name": "missing_count(id) = 0",
#       "type": "metricThreshold",
#       "definition": "checks for snapshot:\n  missing_count(id) = 0",
#       "location": {
#         "filePath": "sodacl_string.yml",
#         "line": 15,
#         "col": 5
#       },
#       "dataSource": "snapshot",
#       "table": "snapshot",
#       "column": "id",
#       "metrics": [
#         "metric-snapshot-snapshot-id-missing_count"
#       ],
#       "outcome": "pass",
#       "diagnostics": {
#         "value": 0,
#         "fail": {
#           "greaterThan": 0.0,
#           "lessThan": 0.0
#         }
#       }
#     },
#     {
#       "identity": "bd933496",
#       "name": "duplicate_count(mail) = 0",
#       "type": "metricThreshold",
#       "definition": "checks for snapshot:\n  duplicate_count(mail) = 0",
#       "location": {
#         "filePath": "sodacl_string.yml",
#         "line": 14,
#         "col": 5
#       },
#       "dataSource": "snapshot",
#       "table": "snapshot",
#       "column": "mail",
#       "metrics": [
#         "metric-snapshot-snapshot-mail-duplicate_count"
#       ],
#       "outcome": "pass",
#       "diagnostics": {
#         "value": 0,
#         "fail": {
#           "greaterThan": 0.0,
#           "lessThan": 0.0
#         }
#       }
#     },
#     {
#       "identity": "55ab369a",
#       "name": "invalid_count(mail) = 0",
#       "type": "metricThreshold",
#       "definition": "checks for snapshot:\n  - invalid_count(mail) = 0:\n      valid format: email\n",
#       "location": {
#         "filePath": "sodacl_string.yml",
#         "line": 16,
#         "col": 5
#       },
#       "dataSource": "snapshot",
#       "table": "snapshot",
#       "column": "mail",
#       "metrics": [
#         "metric-snapshot-snapshot-mail-invalid_count-61813b33"
#       ],
#       "outcome": "pass",
#       "diagnostics": {
#         "value": 0,
#         "fail": {
#           "greaterThan": 0.0,
#           "lessThan": 0.0
#         }
#       }
#     },
#     {
#       "identity": "450977ba",
#       "name": "invalid_percent(birthdate) = 0",
#       "type": "metricThreshold",
#       "definition": "checks for snapshot:\n  - invalid_percent(birthdate) = 0:\n      valid length: 10\n",
#       "location": {
#         "filePath": "sodacl_string.yml",
#         "line": 18,
#         "col": 5
#       },
#       "dataSource": "snapshot",
#       "table": "snapshot",
#       "column": "birthdate",
#       "metrics": [
#         "metric-snapshot-snapshot-birthdate-invalid_percent-80094729"
#       ],
#       "outcome": "pass",
#       "diagnostics": {
#         "value": 0.0,
#         "fail": {
#           "greaterThan": 0.0,
#           "lessThan": 0.0
#         }
#       }
#     }
#   ],
#   "automatedMonitoringChecks": [],
#   "profiling": [
#     {
#       "table": "snapshot",
#       "dataSource": "snapshot",
#       "columnProfiles": [
#         {
#           "columnName": "id",
#           "profile": {
#             "mins": [
#               0.0,
#               1.0,
#               3.0,
#               4.0,
#               6.0
#             ],
#             "maxs": [
#               19.0,
#               18.0,
#               17.0,
#               16.0,
#               15.0
#             ],
#             "min": 0.0,
#             "max": 19.0,
#             "frequent_values": [
#               {
#                 "value": "12",
#                 "frequency": 1
#               },
#               {
#                 "value": "1",
#                 "frequency": 1
#               },
#               {
#                 "value": "13",
#                 "frequency": 1
#               },
#               {
#                 "value": "6",
#                 "frequency": 1
#               },
#               {
#                 "value": "16",
#                 "frequency": 1
#               },
#               {
#                 "value": "3",
#                 "frequency": 1
#               },
#               {
#                 "value": "19",
#                 "frequency": 1
#               },
#               {
#                 "value": "15",
#                 "frequency": 1
#               },
#               {
#                 "value": "9",
#                 "frequency": 1
#               },
#               {
#                 "value": "17",
#                 "frequency": 1
#               }
#             ],
#             "avg": 10.5,
#             "sum": 147.0,
#             "stddev": 6.583779601881721,
#             "variance": 43.34615384615384,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": {
#               "boundaries": [
#                 0.0,
#                 1.46,
#                 2.92,
#                 4.38,
#                 5.85,
#                 7.31,
#                 8.77,
#                 10.23,
#                 11.69,
#                 13.15,
#                 14.62,
#                 16.08,
#                 17.54,
#                 19.0
#               ],
#               "frequencies": [
#                 2,
#                 0,
#                 2,
#                 0,
#                 1,
#                 0,
#                 1,
#                 0,
#                 2,
#                 1,
#                 2,
#                 1,
#                 1,
#                 1
#               ]
#             },
#             "avg_length": null,
#             "min_length": null,
#             "max_length": null
#           }
#         },
#         {
#           "columnName": "job",
#           "profile": {
#             "mins": null,
#             "maxs": null,
#             "min": null,
#             "max": null,
#             "frequent_values": [
#               {
#                 "value": "Contractor",
#                 "frequency": 1
#               },
#               {
#                 "value": "Rural practice surveyor",
#                 "frequency": 1
#               },
#               {
#                 "value": "Museum education officer",
#                 "frequency": 1
#               },
#               {
#                 "value": "Secondary school teacher",
#                 "frequency": 1
#               },
#               {
#                 "value": "Pathologist",
#                 "frequency": 1
#               },
#               {
#                 "value": "Race relations officer",
#                 "frequency": 1
#               },
#               {
#                 "value": "Surveyor, rural practice",
#                 "frequency": 1
#               },
#               {
#                 "value": "Newspaper journalist",
#                 "frequency": 1
#               },
#               {
#                 "value": "Surveyor, commercial/residential",
#                 "frequency": 1
#               },
#               {
#                 "value": "Geologist, engineering",
#                 "frequency": 1
#               }
#             ],
#             "avg": null,
#             "sum": null,
#             "stddev": null,
#             "variance": null,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": null,
#             "avg_length": 20,
#             "min_length": 10,
#             "max_length": 32
#           }
#         },
#         {
#           "columnName": "company",
#           "profile": {
#             "mins": null,
#             "maxs": null,
#             "min": null,
#             "max": null,
#             "frequent_values": [
#               {
#                 "value": "Hernandez Ltd",
#                 "frequency": 1
#               },
#               {
#                 "value": "Gordon-Smith",
#                 "frequency": 1
#               },
#               {
#                 "value": "Baldwin Group",
#                 "frequency": 1
#               },
#               {
#                 "value": "Rodriguez-Williams",
#                 "frequency": 1
#               },
#               {
#                 "value": "Alexander-Weaver",
#                 "frequency": 1
#               },
#               {
#                 "value": "Boone, Gallagher and Scott",
#                 "frequency": 1
#               },
#               {
#                 "value": "Kelly-Singh",
#                 "frequency": 1
#               },
#               {
#                 "value": "Osborne PLC",
#                 "frequency": 1
#               },
#               {
#                 "value": "Jackson-Davis",
#                 "frequency": 1
#               },
#               {
#                 "value": "Larson PLC",
#                 "frequency": 1
#               }
#             ],
#             "avg": null,
#             "sum": null,
#             "stddev": null,
#             "variance": null,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": null,
#             "avg_length": 15,
#             "min_length": 9,
#             "max_length": 28
#           }
#         },
#         {
#           "columnName": "ssn",
#           "profile": {
#             "mins": null,
#             "maxs": null,
#             "min": null,
#             "max": null,
#             "frequent_values": [
#               {
#                 "value": "861-51-6071",
#                 "frequency": 1
#               },
#               {
#                 "value": "586-63-4366",
#                 "frequency": 1
#               },
#               {
#                 "value": "798-56-9807",
#                 "frequency": 1
#               },
#               {
#                 "value": "412-92-6966",
#                 "frequency": 1
#               },
#               {
#                 "value": "508-98-7365",
#                 "frequency": 1
#               },
#               {
#                 "value": "418-26-0136",
#                 "frequency": 1
#               },
#               {
#                 "value": "402-72-6549",
#                 "frequency": 1
#               },
#               {
#                 "value": "627-52-4610",
#                 "frequency": 1
#               },
#               {
#                 "value": "498-01-2910",
#                 "frequency": 1
#               },
#               {
#                 "value": "308-98-1651",
#                 "frequency": 1
#               }
#             ],
#             "avg": null,
#             "sum": null,
#             "stddev": null,
#             "variance": null,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": null,
#             "avg_length": 11,
#             "min_length": 11,
#             "max_length": 11
#           }
#         },
#         {
#           "columnName": "website",
#           "profile": {
#             "mins": null,
#             "maxs": null,
#             "min": null,
#             "max": null,
#             "frequent_values": [
#               {
#                 "value": "['https://evans.info/', 'http://www.choi.com/']",
#                 "frequency": 1
#               },
#               {
#                 "value": "['https://turner-hunter.org/', 'http://www.fields-vang.org/', 'http://morales-zuniga.com/', 'http://www.reyes.com/']",
#                 "frequency": 1
#               },
#               {
#                 "value": "['http://www.hart.com/', 'http://www.edwards.com/', 'https://howard-molina.com/', 'https://www.lynch.com/']",
#                 "frequency": 1
#               },
#               {
#                 "value": "['https://www.lara.com/', 'https://www.hampton.com/']",
#                 "frequency": 1
#               },
#               {
#                 "value": "['http://www.english.com/', 'https://wilson.com/', 'http://www.sanders.com/', 'http://www.pacheco.com/']",
#                 "frequency": 1
#               },
#               {
#                 "value": "['http://www.jackson.com/']",
#                 "frequency": 1
#               },
#               {
#                 "value": "['https://www.pearson.com/', 'http://carlson.com/', 'http://booker.org/', 'https://white-clark.com/']",
#                 "frequency": 1
#               },
#               {
#                 "value": "['https://morgan.com/', 'https://www.gordon.com/', 'http://snyder.com/', 'https://www.reid.com/']",
#                 "frequency": 1
#               },
#               {
#                 "value": "['https://www.turner.com/', 'http://www.merritt.net/', 'http://nelson.biz/', 'http://pena.com/']",
#                 "frequency": 1
#               },
#               {
#                 "value": "['https://shah.net/', 'https://www.cohen-white.com/']",
#                 "frequency": 1
#               }
#             ],
#             "avg": null,
#             "sum": null,
#             "stddev": null,
#             "variance": null,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": null,
#             "avg_length": 74,
#             "min_length": 22,
#             "max_length": 116
#           }
#         },
#         {
#           "columnName": "username",
#           "profile": {
#             "mins": null,
#             "maxs": null,
#             "min": null,
#             "max": null,
#             "frequent_values": [
#               {
#                 "value": "lauraboyle",
#                 "frequency": 1
#               },
#               {
#                 "value": "hbryant",
#                 "frequency": 1
#               },
#               {
#                 "value": "hesterandrew",
#                 "frequency": 1
#               },
#               {
#                 "value": "gphillips",
#                 "frequency": 1
#               },
#               {
#                 "value": "matthew14",
#                 "frequency": 1
#               },
#               {
#                 "value": "johnsonrichard",
#                 "frequency": 1
#               },
#               {
#                 "value": "rpeterson",
#                 "frequency": 1
#               },
#               {
#                 "value": "andreawhite",
#                 "frequency": 1
#               },
#               {
#                 "value": "harriscarl",
#                 "frequency": 1
#               },
#               {
#                 "value": "kdavis",
#                 "frequency": 1
#               }
#             ],
#             "avg": null,
#             "sum": null,
#             "stddev": null,
#             "variance": null,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": null,
#             "avg_length": 10,
#             "min_length": 6,
#             "max_length": 14
#           }
#         },
#         {
#           "columnName": "name",
#           "profile": {
#             "mins": null,
#             "maxs": null,
#             "min": null,
#             "max": null,
#             "frequent_values": [
#               {
#                 "value": "Lori Kline",
#                 "frequency": 1
#               },
#               {
#                 "value": "Samuel Mack",
#                 "frequency": 1
#               },
#               {
#                 "value": "Misty Phillips",
#                 "frequency": 1
#               },
#               {
#                 "value": "Courtney Gonzalez",
#                 "frequency": 1
#               },
#               {
#                 "value": "Veronica Maldonado",
#                 "frequency": 1
#               },
#               {
#                 "value": "Keith Todd",
#                 "frequency": 1
#               },
#               {
#                 "value": "Sally Davis",
#                 "frequency": 1
#               },
#               {
#                 "value": "Jill Anderson",
#                 "frequency": 1
#               },
#               {
#                 "value": "Kelsey Ramsey",
#                 "frequency": 1
#               },
#               {
#                 "value": "Alfred Hall",
#                 "frequency": 1
#               }
#             ],
#             "avg": null,
#             "sum": null,
#             "stddev": null,
#             "variance": null,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": null,
#             "avg_length": 13,
#             "min_length": 10,
#             "max_length": 18
#           }
#         },
#         {
#           "columnName": "address",
#           "profile": {
#             "mins": null,
#             "maxs": null,
#             "min": null,
#             "max": null,
#             "frequent_values": [
#               {
#                 "value": "4978 Chapman Bypass\nSanchezfurt, TN 23177",
#                 "frequency": 1
#               },
#               {
#                 "value": "98150 Jones Way Apt. 251\nJonesside, OK 11215",
#                 "frequency": 1
#               },
#               {
#                 "value": "32860 Yoder Oval\nJeffreyborough, NM 31331",
#                 "frequency": 1
#               },
#               {
#                 "value": "PSC 6263, Box 1355\nAPO AP 32636",
#                 "frequency": 1
#               },
#               {
#                 "value": "2024 Hodge Radial\nStefaniechester, NY 38154",
#                 "frequency": 1
#               },
#               {
#                 "value": "97126 Gary Glens Suite 847\nPort Katherine, NM 13982",
#                 "frequency": 1
#               },
#               {
#                 "value": "36377 Christensen Fort\nPort Justin, OR 51565",
#                 "frequency": 1
#               },
#               {
#                 "value": "67190 Davis Court\nWilliamshaven, WI 02095",
#                 "frequency": 1
#               },
#               {
#                 "value": "928 Sara Vista\nTaylorborough, VA 52559",
#                 "frequency": 1
#               },
#               {
#                 "value": "280 Lindsey Road Apt. 412\nSouth Melissabury, MS 57244",
#                 "frequency": 1
#               }
#             ],
#             "avg": null,
#             "sum": null,
#             "stddev": null,
#             "variance": null,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": null,
#             "avg_length": 42,
#             "min_length": 31,
#             "max_length": 53
#           }
#         },
#         {
#           "columnName": "mail",
#           "profile": {
#             "mins": null,
#             "maxs": null,
#             "min": null,
#             "max": null,
#             "frequent_values": [
#               {
#                 "value": "ana51@yahoo.com",
#                 "frequency": 1
#               },
#               {
#                 "value": "moseslarry@yahoo.com",
#                 "frequency": 1
#               },
#               {
#                 "value": "xchavez@hotmail.com",
#                 "frequency": 1
#               },
#               {
#                 "value": "reedchristopher@gmail.com",
#                 "frequency": 1
#               },
#               {
#                 "value": "shawn57@yahoo.com",
#                 "frequency": 1
#               },
#               {
#                 "value": "kaitlyn23@yahoo.com",
#                 "frequency": 1
#               },
#               {
#                 "value": "shannonscott@yahoo.com",
#                 "frequency": 1
#               },
#               {
#                 "value": "michael49@hotmail.com",
#                 "frequency": 1
#               },
#               {
#                 "value": "sanchezandrew@gmail.com",
#                 "frequency": 1
#               },
#               {
#                 "value": "xpaul@yahoo.com",
#                 "frequency": 1
#               }
#             ],
#             "avg": null,
#             "sum": null,
#             "stddev": null,
#             "variance": null,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": null,
#             "avg_length": 19,
#             "min_length": 15,
#             "max_length": 25
#           }
#         },
#         {
#           "columnName": "birthdate",
#           "profile": {
#             "mins": null,
#             "maxs": null,
#             "min": null,
#             "max": null,
#             "frequent_values": [
#               {
#                 "value": "2012-05-20",
#                 "frequency": 1
#               },
#               {
#                 "value": "1923-10-30",
#                 "frequency": 1
#               },
#               {
#                 "value": "1922-03-06",
#                 "frequency": 1
#               },
#               {
#                 "value": "1995-04-18",
#                 "frequency": 1
#               },
#               {
#                 "value": "1924-09-05",
#                 "frequency": 1
#               },
#               {
#                 "value": "1987-06-05",
#                 "frequency": 1
#               },
#               {
#                 "value": "1996-12-21",
#                 "frequency": 1
#               },
#               {
#                 "value": "1922-03-12",
#                 "frequency": 1
#               },
#               {
#                 "value": "1932-05-02",
#                 "frequency": 1
#               },
#               {
#                 "value": "2003-02-07",
#                 "frequency": 1
#               }
#             ],
#             "avg": null,
#             "sum": null,
#             "stddev": null,
#             "variance": null,
#             "distinct": 14,
#             "missing_count": 0,
#             "histogram": null,
#             "avg_length": 10,
#             "min_length": 10,
#             "max_length": 10
#           }
#         }
#       ]
#     }
#   ],
#   "metadata": [
#     {
#       "table": "snapshot",
#       "dataSource": "snapshot",
#       "rowCount": 14,
#       "schema": [
#         {
#           "columnName": "id",
#           "sourceDataType": "int"
#         },
#         {
#           "columnName": "job",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "company",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "ssn",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "website",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "username",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "name",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "address",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "mail",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "birthdate",
#           "sourceDataType": "string"
#         },
#         {
#           "columnName": "_delivery_date",
#           "sourceDataType": "timestamp"
#         },
#         {
#           "columnName": "",
#           "sourceDataType": ""
#         },
#         {
#           "columnName": "# Partitioning",
#           "sourceDataType": ""
#         },
#         {
#           "columnName": "Not partitioned",
#           "sourceDataType": ""
#         }
#       ]
#     }
#   ],
#   "logs": [
#     {
#       "level": "info",
#       "message": "Soda Core 3.0.4",
#       "timestamp": "2022-08-21T16:36:57+00:00",
#       "index": 1
#     },
#     {
#       "level": "info",
#       "message": "Running discover datasets for data source: snapshot",
#       "timestamp": "2022-08-21T16:37:07+00:00",
#       "index": 2
#     },
#     {
#       "level": "info",
#       "message": "Discovering the following tables:",
#       "timestamp": "2022-08-21T16:37:07+00:00",
#       "index": 3
#     },
#     {
#       "level": "info",
#       "message": "  - snapshot",
#       "timestamp": "2022-08-21T16:37:07+00:00",
#       "index": 4
#     },
#     {
#       "level": "info",
#       "message": "Running column profiling for data source: snapshot",
#       "timestamp": "2022-08-21T16:37:08+00:00",
#       "index": 5
#     },
#     {
#       "level": "info",
#       "message": "Profiling columns for the following tables:",
#       "timestamp": "2022-08-21T16:37:08+00:00",
#       "index": 6
#     },
#     {
#       "level": "info",
#       "message": "  - snapshot",
#       "timestamp": "2022-08-21T16:37:08+00:00",
#       "index": 7
#     },
#     {
#       "level": "info",
#       "message": "Scan summary:",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 8
#     },
#     {
#       "level": "info",
#       "message": "7/8 checks PASSED: ",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 9
#     },
#     {
#       "level": "info",
#       "message": "    snapshot in snapshot",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 10
#     },
#     {
#       "level": "info",
#       "message": "      row_count > 0 [PASSED]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 11
#     },
#     {
#       "level": "info",
#       "message": "      freshness(_delivery_date, FAKE_NOW) < 8d [PASSED]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 12
#     },
#     {
#       "level": "info",
#       "message": "      duplicate_count(id) = 0 [PASSED]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 13
#     },
#     {
#       "level": "info",
#       "message": "      missing_count(id) = 0 [PASSED]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 14
#     },
#     {
#       "level": "info",
#       "message": "      duplicate_count(mail) = 0 [PASSED]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 15
#     },
#     {
#       "level": "info",
#       "message": "      invalid_count(mail) = 0 [PASSED]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 16
#     },
#     {
#       "level": "info",
#       "message": "      invalid_percent(birthdate) = 0 [PASSED]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 17
#     },
#     {
#       "level": "info",
#       "message": "1/8 checks WARNED: ",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 18
#     },
#     {
#       "level": "info",
#       "message": "    snapshot in snapshot",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 19
#     },
#     {
#       "level": "info",
#       "message": "      Schema Check [WARNED]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 20
#     },
#     {
#       "level": "info",
#       "message": "        missing_column_names = [_last_modified_timestamp]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 21
#     },
#     {
#       "level": "info",
#       "message": "        schema_measured = [id int, job string, company string, ssn string, website string, username string, name string, address string, mail string, birthdate string, _delivery_date timestamp,  , # Partitioning , Not partitioned ]",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 22
#     },
#     {
#       "level": "info",
#       "message": "Only 1 warning. 0 failure. 0 errors. 7 pass.",
#       "timestamp": "2022-08-21T16:37:40+00:00",
#       "index": 23
#     }
#   ]
# }
